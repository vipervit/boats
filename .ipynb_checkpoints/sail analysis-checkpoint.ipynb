# %%
import seaborn as sns

# %%
import pandas as pd

# %%
from lib.common import *
from lib.boat import boat

# %%
sails = ['Nr.1', 'Nr.2', 'Nr.3', 'Stormjib', 'Mainsail', 'Genaker', 'Mizzen', 'Mizzen staysail']

# %%
df_base=boat('Petsamo').get_sail_data()
df_base
# Out:
#                                 tws  spd  twd  twa  \
# 2023-01-06 22:49:18.300585032  24.0  8.0  134  158
# 2023-01-07 05:07:22.956870556  25.0  8.0  137  164
# 2023-01-07 12:44:23.910266638  21.0  8.0  130  169
# 2023-01-07 14:56:50.259599923  20.0  8.0  126  141
# 2023-01-07 14:58:51.486292124  21.0  7.0  129  142
# ...                             ...  ...  ...  ...
# 2023-01-20 00:54:49.990070105  19.4  5.7  296   45
# 2023-01-20 02:51:41.800625563  19.0  5.7  294  -45
# 2023-01-20 13:57:32.897197723  22.8  5.8  293   45
# 2023-01-20 16:41:16.019813299  20.5  5.7  288   45
# 2023-01-20 19:06:25.212946892  15.8  5.9  271  -52
#
#                                                                          sails  \
# 2023-01-06 22:49:18.300585032        [Mainsail, Mizzen, Mizzen staysail, Nr.2]
# 2023-01-07 05:07:22.956870556                         [Mainsail, Mizzen, Nr.3]
# 2023-01-07 12:44:23.910266638  [Mainsail, Mizzen, Mizzen staysail, Nr.1, Nr.3]
# 2023-01-07 14:56:50.259599923  [Mainsail, Mizzen, Mizzen staysail, Nr.2, Nr.3]
# 2023-01-07 14:58:51.486292124  [Mainsail, Mizzen, Mizzen staysail, Nr.2, Nr.3]
# ...                                                                        ...
# 2023-01-20 00:54:49.990070105                                 [Mainsail, Nr.2]
# 2023-01-20 02:51:41.800625563                                 [Mainsail, Nr.2]
# 2023-01-20 13:57:32.897197723                         [Mainsail, Mizzen, Nr.3]
# 2023-01-20 16:41:16.019813299                                       [Mainsail]
# 2023-01-20 19:06:25.212946892                         [Mainsail, Mizzen, Nr.2]
#
#                                heel
# 2023-01-06 22:49:18.300585032   NaN
# 2023-01-07 05:07:22.956870556   NaN
# 2023-01-07 12:44:23.910266638   NaN
# 2023-01-07 14:56:50.259599923   NaN
# 2023-01-07 14:58:51.486292124   NaN
# ...                             ...
# 2023-01-20 00:54:49.990070105  32.0
# 2023-01-20 02:51:41.800625563 -31.0
# 2023-01-20 13:57:32.897197723  35.0
# 2023-01-20 16:41:16.019813299  36.0
# 2023-01-20 19:06:25.212946892 -30.0
#
# [101 rows x 6 columns]

# %%
df = df_base.copy()
df = df.reset_index(drop=True)
df
# Out:
#       tws  spd  twd  twa                                            sails  \
# 0    24.0  8.0  134  158        [Mainsail, Mizzen, Mizzen staysail, Nr.2]
# 1    25.0  8.0  137  164                         [Mainsail, Mizzen, Nr.3]
# 2    21.0  8.0  130  169  [Mainsail, Mizzen, Mizzen staysail, Nr.1, Nr.3]
# 3    20.0  8.0  126  141  [Mainsail, Mizzen, Mizzen staysail, Nr.2, Nr.3]
# 4    21.0  7.0  129  142  [Mainsail, Mizzen, Mizzen staysail, Nr.2, Nr.3]
# ..    ...  ...  ...  ...                                              ...
# 96   19.4  5.7  296   45                                 [Mainsail, Nr.2]
# 97   19.0  5.7  294  -45                                 [Mainsail, Nr.2]
# 98   22.8  5.8  293   45                         [Mainsail, Mizzen, Nr.3]
# 99   20.5  5.7  288   45                                       [Mainsail]
# 100  15.8  5.9  271  -52                         [Mainsail, Mizzen, Nr.2]
#
#      heel
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# ..    ...
# 96   32.0
# 97  -31.0
# 98   35.0
# 99   36.0
# 100 -30.0
#
# [101 rows x 6 columns]

# %%
dict_df_by_sail = {}
for sail in sails:
    dict_df_by_sail.update( {sail: df.iloc[[idx for idx in df.index if sail in df.loc[idx]['sails']]]} )

# %%
dict_df_by_sail['Nr.3']['tws'].mean().round()
# Out:
# 13.0

# %%
print('Average wind speed: {}kn'.format(round(df_base['tws'].mean())))

# %%
print('Average boat speed: {}kn'.format(round(df_base['spd'].mean())))

# %%
print('Average boat speed to wind speed: {}%'.format(round(df_base['spd'].mean() / df_base['tws'].mean() * 100)))

# %%
df_sail_usage = pd.DataFrame([dict_df_by_sail[sail]['tws'].mean().round()  for sail in sails], [sail for sail in sails], columns=['TWS'])

# %%
df_sail_usage.sort_index(inplace=True)

# %%
df_sail_usage

# %%
sns.set(rc={'figure.figsize':(10,4)})
sns.barplot(data=df_sail_usage, x=df_sail_usage.index, y='TWS')
