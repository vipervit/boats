# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
from lib.common import *
from lib.boat import boat

# %%
boatname = 'Petsamo'

sails = ['Nr.1', 'Nr.2', 'Nr.3', 'Stormjib', 'Mainsail', 'Genaker', 'Mizzen', 'Mizzen staysail']
points_of_sail={
    'close haul': list(range(0,37)),
    'close reach': list(range(36,73)),
    'beam': list(range(72,109)),
    'broad reach': list(range(108,145)),
    'run': list(range(144,181))
}
yesmark = 'x'
nomark = '-'

# %%
df=boat(boatname).get_sail_data()
df.dropna(inplace=True)
df['heel']=df['heel'].apply(lambda x: int(abs(x)))
df['twa']=df['twa'].apply(lambda x: abs(x))
df=df[df['spd']!=0]
df['spd / tws']=round(df['spd']/df['tws'],2)
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#     tws  spd  twd  twa                                              sails  \
# 0  13.8  6.7  134   86          [Mainsail, Mizzen, Mizzen staysail, Nr.2]
# 1  12.3  3.4  132  127                           [Mainsail, Mizzen, Nr.2]
# 2  13.8  6.7  133   86          [Mainsail, Mizzen, Mizzen staysail, Nr.2]
# 3  13.8  6.6  133   86          [Mainsail, Mizzen, Mizzen staysail, Nr.2]
# 4  13.8  5.8  133  164  [Mainsail, Mizzen, Genaker, Mizzen staysail, N...
#
#    heel  spd / tws
# 0    34       0.49
# 1    25       0.28
# 2    32       0.49
# 3    35       0.48
# 4    15       0.42

# %% [markdown]
# #### Expand sail data:

# %%
for i in range(len(df.index)):
    for sail in sails:
        if sail in df.iloc[i]['sails']:
            mark = yesmark
        else:
            mark = nomark
        df.at[i, sail] = mark
        
df.drop(['sails'], axis=1, inplace=True)
df.head()
# Out:
#     tws  spd  twd  twa  heel  spd / tws Nr.1 Nr.2 Nr.3 Stormjib Mainsail  \
# 0  13.8  6.7  134   86    34       0.49    -    x    -        -        x
# 1  12.3  3.4  132  127    25       0.28    -    x    -        -        x
# 2  13.8  6.7  133   86    32       0.49    -    x    -        -        x
# 3  13.8  6.6  133   86    35       0.48    -    x    -        -        x
# 4  13.8  5.8  133  164    15       0.42    -    -    x        -        x
#
#   Genaker Mizzen Mizzen staysail
# 0       -      x               x
# 1       -      x               -
# 2       -      x               x
# 3       -      x               x
# 4       x      x               x

# %%
df['pos'] = [name for i in df.index for name in points_of_sail if df.iloc[i]['twa'] in points_of_sail[name]]
df
# Out:
#       tws  spd  twd  twa  heel  spd / tws Nr.1 Nr.2 Nr.3 Stormjib Mainsail  \
# 0    13.8  6.7  134   86    34       0.49    -    x    -        -        x
# 1    12.3  3.4  132  127    25       0.28    -    x    -        -        x
# 2    13.8  6.7  133   86    32       0.49    -    x    -        -        x
# 3    13.8  6.6  133   86    35       0.48    -    x    -        -        x
# 4    13.8  5.8  133  164    15       0.42    -    -    x        -        x
# ..    ...  ...  ...  ...   ...        ...  ...  ...  ...      ...      ...
# 99   11.9  5.3  299   45    23       0.45    -    x    -        -        x
# 100  11.9  5.3  299   45    23       0.45    -    x    -        -        x
# 101  12.2  5.3  302   45    26       0.43    -    x    -        -        x
# 102  14.3  5.5  314   45    27       0.38    -    x    -        -        x
# 103  15.2  5.3  316   45    34       0.35    -    x    -        -        x
#
#     Genaker Mizzen Mizzen staysail          pos
# 0         -      x               x         beam
# 1         -      x               -  broad reach
# 2         -      x               x         beam
# 3         -      x               x         beam
# 4         x      x               x          run
# ..      ...    ...             ...          ...
# 99        -      x               -  close reach
# 100       -      x               -  close reach
# 101       -      x               -  close reach
# 102       -      x               -  close reach
# 103       -      x               -  close reach
#
# [104 rows x 15 columns]

# %%
sns.regplot(df, x='tws', y='spd').set(title='spd to tws')
# Out:
# [Text(0.5, 1.0, 'spd to tws')]

# %%
for sail in sails:
    sns.lmplot(df, x='tws', y='spd', hue=sail).set(title='spd to tws by sail')

# %%
sns.lmplot(df, x='tws', y='heel').set(title='heel by tws')

# %%
sns.lmplot(df, x='tws', y='spd / tws').set(title='Speed efficiency to tws')

# %%
df_pos=df.sort_values('twa')[['pos'] + sails].reset_index(drop=True)
df_pos
# Out:
#              pos Nr.1 Nr.2 Nr.3 Stormjib Mainsail Genaker Mizzen  \
# 0     close haul    -    x    -        -        x       -      -
# 1    close reach    -    x    -        -        x       -      -
# 2    close reach    -    x    -        -        x       -      x
# 3    close reach    -    x    -        -        x       -      -
# 4    close reach    -    x    -        -        x       -      x
# ..           ...  ...  ...  ...      ...      ...     ...    ...
# 99           run    -    -    x        -        x       x      x
# 100          run    -    -    x        -        x       x      x
# 101          run    -    -    x        -        x       x      x
# 102          run    -    -    x        -        x       x      x
# 103          run    -    -    x        -        x       x      x
#
#     Mizzen staysail
# 0                 -
# 1                 -
# 2                 -
# 3                 -
# 4                 -
# ..              ...
# 99                x
# 100               x
# 101               x
# 102               x
# 103               x
#
# [104 rows x 9 columns]

# %%
df_pos=df_pos.replace(yesmark, 1)
df_pos=df_pos.replace(nomark, 0)
df_pos
# Out:
#              pos  Nr.1  Nr.2  Nr.3  Stormjib  Mainsail  Genaker  Mizzen  \
# 0     close haul     0     1     0         0         1        0       0
# 1    close reach     0     1     0         0         1        0       0
# 2    close reach     0     1     0         0         1        0       1
# 3    close reach     0     1     0         0         1        0       0
# 4    close reach     0     1     0         0         1        0       1
# ..           ...   ...   ...   ...       ...       ...      ...     ...
# 99           run     0     0     1         0         1        1       1
# 100          run     0     0     1         0         1        1       1
# 101          run     0     0     1         0         1        1       1
# 102          run     0     0     1         0         1        1       1
# 103          run     0     0     1         0         1        1       1
#
#      Mizzen staysail
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 99                 1
# 100                1
# 101                1
# 102                1
# 103                1
#
# [104 rows x 9 columns]

# %%
df_plot=df_pos.groupby('pos').sum()
df_plot
# Out:
#              Nr.1  Nr.2  Nr.3  Stormjib  Mainsail  Genaker  Mizzen  \
# pos
# beam           14     7     7         0        21        0      21
# broad reach     0     1    10         0        11       10      11
# close haul      0     1     0         0         1        0       0
# close reach     8    44     5         2        64        0      38
# run             0     1     6         0         7        6       7
#
#              Mizzen staysail
# pos
# beam                       4
# broad reach               10
# close haul                 0
# close reach                0
# run                        6

# %%
sns.heatmap(df_plot).set(title='Sail types usage by point of sail')
# Out:
# [Text(0.5, 1.0, 'Sail types usage')]

# %%
sns.countplot(df_pos, x='pos').set(title='Points of sail frequency')
# Out:
# [Text(0.5, 1.0, 'Points of sale frequency')]
