# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
from lib.common import *
from lib.boat import boat

# %%
boatname = 'Petsamo'

sails = ['Nr.1', 'Nr.2', 'Nr.3', 'Stormjib', 'Mainsail', 'Genaker', 'Mizzen', 'Mizzen staysail']
points_of_sail={
    'close haul': list(range(0,37)),
    'close reach': list(range(36,73)),
    'beam': list(range(72,109)),
    'broad reach': list(range(108,145)),
    'run': list(range(144,181))
}
yesmark = 'x'
nomark = '-'

# %%
df=boat(boatname).get_sail_data()
df.dropna(inplace=True)
df['heel']=df['heel'].apply(lambda x: int(abs(x)))
df['twa']=df['twa'].apply(lambda x: abs(x))
df=df[df['spd']!=0]
df['spd / tws']=round(df['spd']/df['tws'],2)
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#     tws  spd  twd  twa                                              sails  \
# 0  13.8  6.7  134   86          [Mainsail, Mizzen, Mizzen staysail, Nr.2]
# 1  12.3  3.4  132  127                           [Mainsail, Mizzen, Nr.2]
# 2  13.8  6.7  133   86          [Mainsail, Mizzen, Mizzen staysail, Nr.2]
# 3  13.8  6.6  133   86          [Mainsail, Mizzen, Mizzen staysail, Nr.2]
# 4  13.8  5.8  133  164  [Mainsail, Mizzen, Genaker, Mizzen staysail, N...
#
#    heel  spd / tws
# 0    34       0.49
# 1    25       0.28
# 2    32       0.49
# 3    35       0.48
# 4    15       0.42

# %%
len(df)
# Out:
# 122

# %% [markdown]
# #### Expand sail data:

# %%
for i in range(len(df.index)):
    for sail in sails:
        if sail in df.iloc[i]['sails']:
            mark = yesmark
        else:
            mark = nomark
        df.at[i, sail] = mark
        
df.drop(['sails'], axis=1, inplace=True)
df.head()
# Out:
#     tws  spd  twd  twa  heel  spd / tws Nr.1 Nr.2 Nr.3 Stormjib Mainsail  \
# 0  13.8  6.7  134   86    34       0.49    -    x    -        -        x
# 1  12.3  3.4  132  127    25       0.28    -    x    -        -        x
# 2  13.8  6.7  133   86    32       0.49    -    x    -        -        x
# 3  13.8  6.6  133   86    35       0.48    -    x    -        -        x
# 4  13.8  5.8  133  164    15       0.42    -    -    x        -        x
#
#   Genaker Mizzen Mizzen staysail
# 0       -      x               x
# 1       -      x               -
# 2       -      x               x
# 3       -      x               x
# 4       x      x               x

# %%
df['pos'] = [name for i in df.index for name in points_of_sail if df.iloc[i]['twa'] in points_of_sail[name]]
df
# Out:
#       tws  spd  twd  twa  heel  spd / tws Nr.1 Nr.2 Nr.3 Stormjib Mainsail  \
# 0    13.8  6.7  134   86    34       0.49    -    x    -        -        x
# 1    12.3  3.4  132  127    25       0.28    -    x    -        -        x
# 2    13.8  6.7  133   86    32       0.49    -    x    -        -        x
# 3    13.8  6.6  133   86    35       0.48    -    x    -        -        x
# 4    13.8  5.8  133  164    15       0.42    -    -    x        -        x
# ..    ...  ...  ...  ...   ...        ...  ...  ...  ...      ...      ...
# 117   4.4  3.5   47  112    13       0.80    -    -    x        -        x
# 118   4.4  3.6   47  112    12       0.82    x    -    x        -        x
# 119   4.4  3.5   46  111    12       0.80    x    -    x        -        x
# 120   4.4  3.5   46  111    12       0.80    x    -    x        -        x
# 121  14.2  6.9   37  109    36       0.49    x    -    x        -        x
#
#     Genaker Mizzen Mizzen staysail          pos
# 0         -      x               x         beam
# 1         -      x               -  broad reach
# 2         -      x               x         beam
# 3         -      x               x         beam
# 4         x      x               x          run
# ..      ...    ...             ...          ...
# 117       x      x               x  broad reach
# 118       -      x               x  broad reach
# 119       -      x               x  broad reach
# 120       -      x               x  broad reach
# 121       -      x               x  broad reach
#
# [122 rows x 15 columns]

# %%
df_plot=df[['pos', 'spd']].groupby('pos').mean().sort_values('pos')
sns.barplot(data=df_plot, x=df_plot.index, y='spd').set(title='Speed by point of sale')
# Out:
# [Text(0.5, 1.0, 'Speed by point of sale')]

# %%
sns.countplot(data=df_pos.sort_values('pos'), x='pos').set(title='Points of sail frequency')
# Out:
# [Text(0.5, 1.0, 'Points of sail frequency')]

# %%
sns.lineplot(data=df[['heel', 'spd']].groupby('heel').mean(), x=df_plot.index, y='spd').set(title='Speed by heel')
# Out:
# [Text(0.5, 1.0, 'Speed by heel')]

# %%
sns.regplot(data=df, x='tws', y='spd').set(title='spd to tws')
# Out:
# [Text(0.5, 1.0, 'spd to tws')]

# %%
sns.lmplot(data=df, x='tws', y='heel').set(title='heel by tws')

# %%
sns.lmplot(data=df, x='tws', y='spd / tws').set(title='Speed efficiency to tws')

# %%
df_pos=df.sort_values('twa')[['pos'] + sails].reset_index(drop=True)
df_pos
# Out:
#              pos Nr.1 Nr.2 Nr.3 Stormjib Mainsail Genaker Mizzen  \
# 0     close haul    -    x    -        -        x       -      -
# 1    close reach    -    x    -        -        x       -      -
# 2    close reach    -    x    -        -        x       -      -
# 3    close reach    -    x    -        -        x       -      -
# 4    close reach    -    x    -        -        x       -      -
# ..           ...  ...  ...  ...      ...      ...     ...    ...
# 117          run    -    -    x        -        x       x      x
# 118          run    -    -    x        -        x       x      x
# 119          run    -    -    x        -        x       x      x
# 120          run    -    -    x        -        x       x      x
# 121          run    -    -    x        -        x       x      x
#
#     Mizzen staysail
# 0                 -
# 1                 -
# 2                 -
# 3                 -
# 4                 -
# ..              ...
# 117               x
# 118               x
# 119               x
# 120               x
# 121               x
#
# [122 rows x 9 columns]

# %%
df_pos=df_pos.replace(yesmark, 1)
df_pos=df_pos.replace(nomark, 0)
df_pos
# Out:
#              pos  Nr.1  Nr.2  Nr.3  Stormjib  Mainsail  Genaker  Mizzen  \
# 0     close haul     0     1     0         0         1        0       0
# 1    close reach     0     1     0         0         1        0       0
# 2    close reach     0     1     0         0         1        0       0
# 3    close reach     0     1     0         0         1        0       0
# 4    close reach     0     1     0         0         1        0       0
# ..           ...   ...   ...   ...       ...       ...      ...     ...
# 117          run     0     0     1         0         1        1       1
# 118          run     0     0     1         0         1        1       1
# 119          run     0     0     1         0         1        1       1
# 120          run     0     0     1         0         1        1       1
# 121          run     0     0     1         0         1        1       1
#
#      Mizzen staysail
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ..               ...
# 117                1
# 118                1
# 119                1
# 120                1
# 121                1
#
# [122 rows x 9 columns]

# %%
df_plot=df_pos.groupby('pos').sum()
df_plot
# Out:
#              Nr.1  Nr.2  Nr.3  Stormjib  Mainsail  Genaker  Mizzen  \
# pos
# beam           14     7     7         0        21        0      21
# broad reach     4     1    21         0        22       17      22
# close haul      0     1     0         0         1        0       0
# close reach    12    45     5         2        69        0      43
# run             0     1     8         0         9        8       9
#
#              Mizzen staysail
# pos
# beam                       4
# broad reach               21
# close haul                 0
# close reach                0
# run                        8

# %%
sns.heatmap(df_plot).set(title='Sail types usage by point of sail')
# Out:
# [Text(0.5, 1.0, 'Sail types usage by point of sail')]

# %%
for sail in sails:
    sns.lmplot(data=df, x='tws', y='spd', hue=sail).set(title='spd to tws by sail')
