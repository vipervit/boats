# %%
import requests
import json
import pandas as pd
import folium
import time
from datetime import datetime
import os
from pathlib import Path

url_race='https://sarl.ingenium.net.au/racelog?racenr=38602'
html=os.path.join(str(Path.home()), 'Documents', 'boats.html')

# %%
res=requests.get(url_race)

# %%
boats = res.json()['result']

# %%
boats
# Out:
# {'Encelade-Voyage Voyage': {'heading': 41,
#   'lat_dec': -28.6192,
#   'lon_dec': 153.7223,
#   'lastreport_heading': '41',
#   'lastreport_speed': '5.3',
#   'sail': '117873',
#   'status': None,
#   'wind': '356°, 15.9kn.',
#   'ubtname': 'Voyage Voyage',
#   'usrname': 'Encelade',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S28°37.154' E153°43.338', Hdg: 41°, Spd: 5.3kn., 3049.7nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 21144,
#   'rank': '1',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859485000.0,
#   'trackdistance': '368.492',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3049.71379719886',
#   'track': [[-28.6192, 153.7223],
#    [-28.9796, 153.6909],
#    [-29.7408, 153.843],
#    [-30.1837, 153.6968],
#    [-30.3274, 153.5014],
#    [-30.7883, 153.5554],
#    [-31.1288, 153.4828],
#    [-31.388, 153.4828],
#    [-31.509, 153.4467],
#    [-31.6306, 153.1994],
#    [-31.7385, 152.8927],
#    [-32.5503, 152.6125],
#    [-32.8815, 152.5129],
#    [-32.9086, 152.1299],
#    [-33.0168, 151.789],
#    [-33.7324, 151.3701]]},
#  'dark one77-Guppy-Maru': {'heading': 1,
#   'lat_dec': -29.4933,
#   'lon_dec': 154.1416,
#   'lastreport_heading': '1',
#   'lastreport_speed': '5.3',
#   'sail': '118246',
#   'status': None,
#   'wind': '46°, 14.8kn.',
#   'ubtname': 'Guppy-Maru',
#   'usrname': 'dark one77',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°29.601' E154°8.496', Hdg: 1°, Spd: 5.3kn., 3103.5nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 20851,
#   'rank': '16',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859542000.0,
#   'trackdistance': '326.713',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3103.49567236719',
#   'track': [[-29.4933, 154.1416],
#    [-29.8127, 154.135],
#    [-30.608, 154.1957],
#    [-30.962, 154.0159],
#    [-30.9909, 153.905],
#    [-31.4208, 153.7892],
#    [-31.6901, 153.5971],
#    [-31.899, 153.4846],
#    [-32.0007, 153.3988],
#    [-32.1047, 153.1245],
#    [-32.1681, 152.735],
#    [-32.8937, 152.3941],
#    [-33.0368, 152.3175],
#    [-33.1634, 152.1983],
#    [-33.1628, 151.7987],
#    [-33.7639, 151.3407]]},
#  'FreeQuest-Lisa Ann': {'heading': 65,
#   'lat_dec': -30.7085,
#   'lon_dec': 154.7831,
#   'lastreport_heading': '65',
#   'lastreport_speed': '5.2',
#   'sail': '127111',
#   'status': None,
#   'wind': '20°, 10.2kn.',
#   'ubtname': 'Lisa Ann',
#   'usrname': 'FreeQuest',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°42.51' E154°46.987', Hdg: 65°, Spd: 5.2kn., 3180.1nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 31362,
#   'rank': '26',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859580000.0,
#   'trackdistance': '285.411',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3180.08836884947',
#   'track': [[-30.7085, 154.7831],
#    [-30.7542, 154.4907],
#    [-31.1531, 154.1545],
#    [-31.6011, 154.0911],
#    [-31.5991, 154.0278],
#    [-31.6833, 153.7054],
#    [-31.9374, 153.5175],
#    [-32.186, 153.4419],
#    [-32.4008, 153.4416],
#    [-32.5186, 153.2638],
#    [-32.752, 153.2677],
#    [-33.1115, 152.6142],
#    [-33.3998, 152.5628],
#    [-33.4632, 152.2863],
#    [-33.6346, 152.0428],
#    [-33.7546, 151.3763]]},
#  'Steiger-Ketch I': {'heading': 141,
#   'lat_dec': -37.0438,
#   'lon_dec': 150.3001,
#   'lastreport_heading': '141',
#   'lastreport_speed': '5.7',
#   'sail': '128434',
#   'status': None,
#   'wind': '183°, 25.5kn.',
#   'ubtname': 'Ketch I',
#   'usrname': 'Steiger',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S37°2.629' E150°18.005', Hdg: 141°, Spd: 5.7kn., 3341.5nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 20227,
#   'rank': '29',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859591000.0,
#   'trackdistance': '394.960',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3341.53671523658',
#   'track': [[-37.0438, 150.3001],
#    [-36.791, 150.286],
#    [-36.2432, 150.5207],
#    [-35.7126, 151.0182],
#    [-35.5622, 151.46],
#    [-35.4656, 152.2346],
#    [-35.4912, 152.7237],
#    [-35.3289, 152.9371],
#    [-35.0628, 152.9664],
#    [-34.7794, 152.9715],
#    [-34.5312, 153.1709],
#    [-33.4752, 153.0601],
#    [-33.3657, 152.626],
#    [-33.3716, 152.2996],
#    [-33.4909, 152.0107],
#    [-33.7119, 151.3567]]},
#  'jerry2-My boat': {'heading': 344,
#   'lat_dec': -31.5317,
#   'lon_dec': 153.6971,
#   'lastreport_heading': '344',
#   'lastreport_speed': '4.7',
#   'sail': '129253',
#   'status': None,
#   'wind': '44°, 7.5kn.',
#   'ubtname': 'My boat',
#   'usrname': 'jerry2',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°31.904' E153°41.828', Hdg: 344°, Spd: 4.7kn., 3180.7nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 32686,
#   'rank': '27',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859584000.0,
#   'trackdistance': '260.894',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3180.67051163541',
#   'track': [[-31.5317, 153.6971],
#    [-31.7558, 153.8329],
#    [-31.9262, 153.8488],
#    [-31.8693, 153.5606],
#    [-31.8541, 153.3374],
#    [-32.2322, 153.1654],
#    [-32.5425, 153.182],
#    [-32.7174, 153.0837],
#    [-32.9251, 153.0584],
#    [-33.2284, 153.1968],
#    [-33.5923, 153.2609],
#    [-33.8895, 152.362],
#    [-33.8686, 151.9037],
#    [-33.7869, 151.4322],
#    [-33.7732, 151.3303]]},
#  'pd123-Pete': {'finishtime': '-',
#   'sail': '131603',
#   'status': 'Abandoned race',
#   'wind': None,
#   'ubtname': 'Pete',
#   'usrname': 'pd123',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': '-',
#   'finished': 'true',
#   'teaname': None,
#   'usrnr': 32002,
#   'rank': 'DNF',
#   'btptype': "45' Ketch",
#   'racing': 0,
#   'timestamp': 1672575246000.0,
#   'trackdistance': '0.000',
#   'points': '0',
#   'nextmarknr': None,
#   'distancetonextmark': '3211.69238827861',
#   'track': [[-33.8533, 151.2075]]},
#  'StormGirl-SpaceShip': {'heading': 73,
#   'lat_dec': -29.0054,
#   'lon_dec': 153.5847,
#   'lastreport_heading': '73',
#   'lastreport_speed': '4.5',
#   'sail': '153582',
#   'status': None,
#   'wind': '26°, 8.5kn.',
#   'ubtname': 'SpaceShip',
#   'usrname': 'StormGirl',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°0.324' E153°35.084', Hdg: 73°, Spd: 4.5kn., 3062.2nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 8791,
#   'rank': '4',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859495000.0,
#   'trackdistance': '332.673',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3062.21756989628',
#   'track': [[-29.0054, 153.5847],
#    [-29.3161, 153.5417],
#    [-30.0304, 153.6072],
#    [-30.5213, 153.4752],
#    [-30.7299, 153.5594],
#    [-31.0262, 153.2916],
#    [-31.3537, 153.2249],
#    [-31.6356, 153.2156],
#    [-31.759, 153.1118],
#    [-31.9559, 153.0637],
#    [-32.1247, 152.854],
#    [-32.8503, 152.4769],
#    [-33.1499, 152.4031],
#    [-33.3922, 152.2777],
#    [-33.5077, 151.9896],
#    [-33.8328, 151.4121]]},
#  'Kreole-Beagle II': {'finishtime': '-',
#   'sail': '157904',
#   'status': 'Abandoned race',
#   'wind': None,
#   'ubtname': 'Beagle II',
#   'usrname': 'Kreole',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': '-',
#   'finished': 'true',
#   'teaname': None,
#   'usrnr': 3900,
#   'rank': 'DNF',
#   'btptype': "45' Ketch",
#   'racing': 0,
#   'timestamp': 1672539203000.0,
#   'trackdistance': '0.000',
#   'points': '0',
#   'nextmarknr': None,
#   'distancetonextmark': '3936.40973730328',
#   'track': []},
#  'Chris66-Slowdog': {'heading': 2,
#   'lat_dec': -29.2841,
#   'lon_dec': 153.828,
#   'lastreport_heading': '2',
#   'lastreport_speed': '5.9',
#   'sail': '160273',
#   'status': None,
#   'wind': '59°, 14kn.',
#   'ubtname': 'Slowdog',
#   'usrname': 'Chris66',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°17.044' E153°49.678', Hdg: 2°, Spd: 5.9kn., 3083.2nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 25805,
#   'rank': '14',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859535000.0,
#   'trackdistance': '334.103',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3083.19884008573',
#   'track': [[-29.2841, 153.828],
#    [-29.6216, 153.8253],
#    [-30.3034, 153.7752],
#    [-30.9168, 153.8309],
#    [-31.0308, 153.8226],
#    [-31.4587, 153.7252],
#    [-31.8087, 153.6445],
#    [-32.0765, 153.5966],
#    [-32.2011, 153.5219],
#    [-32.221, 153.1356],
#    [-32.3105, 152.8288],
#    [-32.6552, 152.4605],
#    [-33.0119, 152.3681],
#    [-33.3346, 152.2549],
#    [-33.4728, 151.9779],
#    [-33.7795, 151.3825]]},
#  'Dbird64-Lizzy\n': {'heading': 351,
#   'lat_dec': -29.0666,
#   'lon_dec': 153.6613,
#   'lastreport_heading': '351',
#   'lastreport_speed': '4.9',
#   'sail': '165613',
#   'status': None,
#   'wind': '30°, 11kn.',
#   'ubtname': 'Lizzy\n',
#   'usrname': 'Dbird64',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°3.996' E153°39.676', Hdg: 351°, Spd: 4.9kn., 3067.6nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 6479,
#   'rank': '9',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859517000.0,
#   'trackdistance': '363.403',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3067.6324880716',
#   'track': [[-29.0666, 153.6613],
#    [-29.4183, 153.6377],
#    [-30.11, 153.6225],
#    [-30.7194, 153.7314],
#    [-30.8977, 153.8662],
#    [-31.4577, 153.9825],
#    [-31.7933, 153.9368],
#    [-31.9846, 153.8005],
#    [-32.1924, 153.7853],
#    [-32.2731, 153.5373],
#    [-32.2773, 153.1572],
#    [-33.0082, 152.7984],
#    [-33.0204, 152.5109],
#    [-33.0431, 152.1535],
#    [-33.2029, 151.8543],
#    [-33.7445, 151.3745]]},
#  'PtitGuy-PtitGuy Ketch II': {'heading': 80,
#   'lat_dec': -29.6915,
#   'lon_dec': 153.6237,
#   'lastreport_heading': '80',
#   'lastreport_speed': '5.5',
#   'sail': '173699',
#   'status': None,
#   'wind': '35°, 16.5kn.',
#   'ubtname': 'PtitGuy Ketch II',
#   'usrname': 'PtitGuy',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°41.492' E153°37.42', Hdg: 80°, Spd: 5.5kn., 3094.5nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 14670,
#   'rank': '15',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859538000.0,
#   'trackdistance': '333.613',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3094.49212919563',
#   'track': [[-29.6915, 153.6237],
#    [-29.7847, 153.3697],
#    [-30.2736, 153.2374],
#    [-30.8041, 153.1661],
#    [-30.9217, 153.1706],
#    [-31.4225, 153.2657],
#    [-31.6668, 153.1557],
#    [-31.9333, 153.1369],
#    [-32.1198, 153.1143],
#    [-32.2794, 153.0042],
#    [-32.4963, 152.9701],
#    [-33.4451, 152.9346],
#    [-33.5144, 152.6129],
#    [-33.6592, 152.3852],
#    [-34.0263, 152.2528],
#    [-33.8826, 151.4315]]},
#  'Tony2-gypsy': {'heading': 93,
#   'lat_dec': -30.6408,
#   'lon_dec': 154.2634,
#   'lastreport_heading': '93',
#   'lastreport_speed': '5.2',
#   'sail': '181221',
#   'status': None,
#   'wind': '38°, 13.5kn.',
#   'ubtname': 'gypsy',
#   'usrname': 'Tony2',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°38.45' E154°15.802', Hdg: 93°, Spd: 5.2kn., 3159.2nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 40348,
#   'rank': '23',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859569000.0,
#   'trackdistance': '329.229',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3159.23561413963',
#   'track': [[-30.6408, 154.2634],
#    [-30.6393, 153.9334],
#    [-31.2708, 154.0125],
#    [-31.7176, 153.9937],
#    [-31.825, 154.0029],
#    [-32.0575, 153.7925],
#    [-32.284, 153.5779],
#    [-32.3513, 153.3224],
#    [-32.3265, 152.9696],
#    [-32.5275, 152.9353],
#    [-32.8245, 153.0571],
#    [-33.6025, 152.8601],
#    [-33.4902, 152.4139],
#    [-33.3757, 151.9643],
#    [-33.3078, 151.5359],
#    [-33.7269, 151.3475]]},
#  'Marino dg-Miguel Domenech Martinez   MD': {'heading': 347,
#   'lat_dec': -29.9544,
#   'lon_dec': 154.0879,
#   'lastreport_heading': '347',
#   'lastreport_speed': '5.4',
#   'sail': '183268',
#   'status': None,
#   'wind': '32°, 17.9kn.',
#   'ubtname': 'Miguel Domenech Martinez   MD',
#   'usrname': 'Marino dg',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°57.264' E154°5.274', Hdg: 347°, Spd: 5.4kn., 3122.3nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 45190,
#   'rank': '20',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859557000.0,
#   'trackdistance': '377.967',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3122.31535061944',
#   'track': [[-29.9544, 154.0879],
#    [-30.2941, 154.1242],
#    [-30.9699, 154.0192],
#    [-31.4773, 154.0214],
#    [-31.5994, 154.0492],
#    [-32.0122, 153.9214],
#    [-32.3394, 153.8178],
#    [-32.6681, 153.8251],
#    [-32.9645, 153.8566],
#    [-33.3141, 153.8678],
#    [-33.7203, 153.8335],
#    [-33.7775, 152.9145],
#    [-33.6184, 152.4238],
#    [-33.6493, 152.1007],
#    [-34.065, 152.0379],
#    [-33.8603, 151.3517]]},
#  'Tellize-Celephais': {'heading': 327,
#   'lat_dec': -28.9901,
#   'lon_dec': 153.6602,
#   'lastreport_heading': '327',
#   'lastreport_speed': '5.5',
#   'sail': '191184',
#   'status': None,
#   'wind': '17°, 10.5kn.',
#   'ubtname': 'Celephais',
#   'usrname': 'Tellize',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S28°59.406' E153°39.61', Hdg: 327°, Spd: 5.5kn., 3064.2nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 46913,
#   'rank': '6',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859501000.0,
#   'trackdistance': '335.795',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3064.15760128012',
#   'track': [[-28.9901, 153.6602],
#    [-29.3645, 153.7933],
#    [-30.0335, 153.8783],
#    [-30.4574, 153.7602],
#    [-30.5372, 153.5644],
#    [-30.8268, 153.3161],
#    [-31.1029, 153.2162],
#    [-31.3406, 153.1489],
#    [-31.5337, 153.1128],
#    [-31.6912, 153.2039],
#    [-31.8402, 153.0113],
#    [-32.547, 152.572],
#    [-32.7458, 152.4016],
#    [-32.8919, 152.117],
#    [-33.027, 151.7967],
#    [-33.7534, 151.3853]]},
#  'lesud48-Black sheep': {'heading': 65,
#   'lat_dec': -30.3708,
#   'lon_dec': 153.8111,
#   'lastreport_heading': '65',
#   'lastreport_speed': '5.8',
#   'sail': '195197',
#   'status': None,
#   'wind': '16°, 15.7kn.',
#   'ubtname': 'Black sheep',
#   'usrname': 'lesud48',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°22.249' E153°48.668', Hdg: 65°, Spd: 5.8kn., 3131.6nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 45620,
#   'rank': '22',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859565000.0,
#   'trackdistance': '316.935',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3131.63031117912',
#   'track': [[-30.3708, 153.8111],
#    [-30.5614, 153.715],
#    [-31.1846, 153.7719],
#    [-31.7009, 153.8491],
#    [-31.6844, 153.697],
#    [-32.1546, 153.6387],
#    [-32.5313, 153.6874],
#    [-32.8655, 153.6981],
#    [-33.0211, 153.5847],
#    [-33.1019, 153.2338],
#    [-33.3591, 153.1686],
#    [-33.8975, 152.5119],
#    [-33.8304, 152.0216],
#    [-33.8395, 151.5634],
#    [-33.8554, 151.1996]]},
#  'isla hormiga c.palos-SS CARTAGENA\n': {'heading': 53,
#   'lat_dec': -28.9847,
#   'lon_dec': 153.7362,
#   'lastreport_heading': '53',
#   'lastreport_speed': '5.4',
#   'sail': '216715',
#   'status': None,
#   'wind': '12°, 12.9kn.',
#   'ubtname': 'SS CARTAGENA\n',
#   'usrname': 'isla hormiga c.palos',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S28°59.082' E153°44.169', Hdg: 53°, Spd: 5.4kn., 3066.6nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 33747,
#   'rank': '8',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859514000.0,
#   'trackdistance': '342.096',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3066.5661718775',
#   'track': [[-28.9847, 153.7362],
#    [-29.3153, 153.7604],
#    [-29.8963, 153.6721],
#    [-30.3387, 153.6613],
#    [-30.4757, 153.5673],
#    [-30.9673, 153.6324],
#    [-31.3273, 153.5882],
#    [-31.5948, 153.583],
#    [-31.719, 153.5317],
#    [-31.818, 153.2586],
#    [-31.915, 152.9401],
#    [-32.6859, 152.473],
#    [-33.0057, 152.3689],
#    [-33.3344, 152.2426],
#    [-33.4729, 151.9479],
#    [-33.7427, 151.349]]},
#  'stefan3-My boat': {'heading': 358,
#   'lat_dec': -29.1909,
#   'lon_dec': 153.8754,
#   'lastreport_heading': '358',
#   'lastreport_speed': '5.8',
#   'sail': '220937',
#   'status': None,
#   'wind': '55°, 11.8kn.',
#   'ubtname': 'My boat',
#   'usrname': 'stefan3',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°11.452' E153°52.524', Hdg: 358°, Spd: 5.8kn., 3080.7nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 13249,
#   'rank': '12',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859527000.0,
#   'trackdistance': '348.303',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3080.66987465912',
#   'track': [[-29.1909, 153.8754],
#    [-29.298, 153.6109],
#    [-30.0726, 153.7765],
#    [-30.6492, 153.8376],
#    [-30.7327, 153.7278],
#    [-31.1841, 153.7044],
#    [-31.5463, 153.6501],
#    [-31.6125, 153.4326],
#    [-31.6349, 153.156],
#    [-31.8004, 152.9347],
#    [-31.8922, 152.6731],
#    [-32.6957, 152.4493],
#    [-33.0471, 152.3606],
#    [-33.158, 152.0771],
#    [-33.4011, 151.8473],
#    [-33.7719, 151.3378]]},
#  'bougnette-STELLA\t': {'heading': 43,
#   'lat_dec': -28.8521,
#   'lon_dec': 153.7455,
#   'lastreport_heading': '43',
#   'lastreport_speed': '5.3',
#   'sail': '223932',
#   'status': None,
#   'wind': '0°, 16kn.',
#   'ubtname': 'STELLA\t',
#   'usrname': 'bougnette',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S28°51.126' E153°44.731', Hdg: 43°, Spd: 5.3kn., 3061nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 47593,
#   'rank': '3',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859492000.0,
#   'trackdistance': '361.281',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3060.95074211652',
#   'track': [[-28.8521, 153.7455],
#    [-29.1957, 153.8324],
#    [-29.8987, 153.8908],
#    [-30.2294, 153.4979],
#    [-30.3916, 153.3334],
#    [-30.8569, 153.3918],
#    [-31.1452, 153.2609],
#    [-31.3985, 153.2209],
#    [-31.5877, 153.2157],
#    [-31.7488, 152.9817],
#    [-31.8807, 152.7191],
#    [-32.7383, 152.4683],
#    [-33.069, 152.3815],
#    [-33.4134, 152.2944],
#    [-33.7655, 152.1539],
#    [-33.8861, 151.4487]]},
#  'Buckaroo M-Yoyodyne': {'heading': 351,
#   'lat_dec': -29.1095,
#   'lon_dec': 153.7008,
#   'lastreport_heading': '351',
#   'lastreport_speed': '5.3',
#   'sail': '228494',
#   'status': None,
#   'wind': '36°, 11.9kn.',
#   'ubtname': 'Yoyodyne',
#   'usrname': 'Buckaroo M',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°6.571' E153°42.049', Hdg: 351°, Spd: 5.3kn., 3070.9nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 55403,
#   'rank': '10',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859520000.0,
#   'trackdistance': '412.372',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3070.93734430383',
#   'track': [[-29.1095, 153.7008],
#    [-29.2553, 153.4655],
#    [-30.0228, 153.5574],
#    [-30.657, 153.7834],
#    [-30.8323, 153.8574],
#    [-31.3733, 153.9206],
#    [-31.7516, 153.9693],
#    [-32.046, 154.0046],
#    [-32.2721, 154.0316],
#    [-32.4008, 153.9158],
#    [-32.6672, 153.8169],
#    [-33.8049, 153.5416],
#    [-34.0465, 153.1604],
#    [-34.241, 152.8139],
#    [-34.1822, 152.332],
#    [-33.8869, 151.4246]]},
#  'AB Rich-T E Q U I L A  S U N R I S E': {'heading': 351,
#   'lat_dec': -30.7376,
#   'lon_dec': 154.2041,
#   'lastreport_heading': '351',
#   'lastreport_speed': '5.4',
#   'sail': '234119',
#   'status': None,
#   'wind': '38°, 12.9kn.',
#   'ubtname': 'T E Q U I L A  S U N R I S E',
#   'usrname': 'AB Rich',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°44.257' E154°12.246', Hdg: 351°, Spd: 5.4kn., 3161.6nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 46465,
#   'rank': '24',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859573000.0,
#   'trackdistance': '290.573',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3161.58295841227',
#   'track': [[-30.7376, 154.2041],
#    [-30.9748, 154.1258],
#    [-31.441, 153.967],
#    [-31.8624, 153.8933],
#    [-31.8224, 153.7469],
#    [-32.1183, 153.5622],
#    [-32.3603, 153.5955],
#    [-32.5932, 153.5921],
#    [-32.6003, 153.3851],
#    [-32.6344, 153.1867],
#    [-32.6915, 153.1651],
#    [-33.3753, 152.8716],
#    [-33.6152, 152.6963],
#    [-33.5075, 152.2611],
#    [-33.4293, 151.8494],
#    [-33.8218, 151.3032]]},
#  'Bluemoon TR-NBK': {'heading': 273,
#   'lat_dec': -39.3215,
#   'lon_dec': 147.017,
#   'lastreport_heading': '273',
#   'lastreport_speed': '4.4',
#   'sail': '235249',
#   'status': None,
#   'wind': '99°, 10.1kn.',
#   'ubtname': 'NBK',
#   'usrname': 'Bluemoon TR',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S39°19.289' E147°1.02', Hdg: 273°, Spd: 4.4kn., 3374.5nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 43147,
#   'rank': '30',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859595000.0,
#   'trackdistance': '444.987',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3374.53461911456',
#   'track': [[-39.3215, 147.017],
#    [-39.2659, 147.4393],
#    [-38.9638, 148.1649],
#    [-38.3487, 148.4473],
#    [-38.183, 148.6284],
#    [-38.2575, 149.2287],
#    [-38.111, 149.3746],
#    [-38.2302, 149.7441],
#    [-37.8702, 149.7248],
#    [-37.6834, 149.7568],
#    [-37.5948, 149.9214],
#    [-36.7768, 150.5042],
#    [-36.2386, 150.7969],
#    [-35.6591, 151.1117],
#    [-35.0367, 151.3631],
#    [-33.9654, 151.2819]]},
#  'chony-My boat': {'finishtime': '-',
#   'sail': '242668',
#   'status': 'Abandoned race',
#   'wind': None,
#   'ubtname': 'My boat',
#   'usrname': 'chony',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': '-',
#   'finished': 'true',
#   'teaname': None,
#   'usrnr': 54560,
#   'rank': 'DNF',
#   'btptype': "45' Ketch",
#   'racing': 0,
#   'timestamp': 1672629245000.0,
#   'trackdistance': '0.000',
#   'points': '0',
#   'nextmarknr': None,
#   'distancetonextmark': '3422.58588724002',
#   'track': []},
#  'anbushi-Ketchy Pride': {'heading': 52,
#   'lat_dec': -30.4582,
#   'lon_dec': 153.3441,
#   'lastreport_heading': '52',
#   'lastreport_speed': '4.8',
#   'sail': '249776',
#   'status': None,
#   'wind': '7°, 14.3kn.',
#   'ubtname': 'Ketchy Pride',
#   'usrname': 'anbushi',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°27.49' E153°20.648', Hdg: 52°, Spd: 4.8kn., 3119.8nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 60495,
#   'rank': '18',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859549000.0,
#   'trackdistance': '261.791',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3119.81480180346',
#   'track': [[-30.4582, 153.3441],
#    [-30.5824, 153.0879],
#    [-31.1534, 153.0645],
#    [-31.7475, 153.0274],
#    [-31.8977, 152.9833],
#    [-32.2681, 152.9306],
#    [-32.4097, 152.7879],
#    [-32.6507, 152.755],
#    [-32.6994, 152.4673],
#    [-32.7652, 152.1711],
#    [-33.2643, 152.0335],
#    [-33.4713, 151.9416],
#    [-33.6044, 151.7319],
#    [-33.6053, 151.3569],
#    [-33.8173, 151.2852]]},
#  'LightninCris-PssP2': {'heading': 3,
#   'lat_dec': -29.3457,
#   'lon_dec': 153.7297,
#   'lastreport_heading': '3',
#   'lastreport_speed': '5.4',
#   'sail': '251796',
#   'status': None,
#   'wind': '52°, 16.4kn.',
#   'ubtname': 'PssP2',
#   'usrname': 'LightninCris',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°20.743' E153°43.78', Hdg: 3°, Spd: 5.4kn., 3082.6nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 60837,
#   'rank': '13',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859531000.0,
#   'trackdistance': '347.915',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3082.55713233032',
#   'track': [[-29.3457, 153.7297],
#    [-29.5957, 153.6109],
#    [-30.3246, 153.755],
#    [-30.7773, 153.6084],
#    [-30.8962, 153.5239],
#    [-31.1219, 153.1783],
#    [-31.3865, 153.4272],
#    [-31.5586, 153.6063],
#    [-31.6421, 153.5173],
#    [-31.7338, 153.2193],
#    [-31.8928, 152.9974],
#    [-32.648, 152.4981],
#    [-33.0155, 152.4363],
#    [-33.2061, 152.2162],
#    [-33.1484, 151.7883],
#    [-33.8145, 151.3825]]},
#  '*Seafarer*-HERA': {'heading': 357,
#   'lat_dec': -30.317,
#   'lon_dec': 153.7722,
#   'lastreport_heading': '357',
#   'lastreport_speed': '2.7',
#   'sail': '252228',
#   'status': None,
#   'wind': '17°, 16.1kn.',
#   'ubtname': 'HERA',
#   'usrname': '*Seafarer*',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°19.023' E153°46.329', Hdg: 357°, Spd: 2.7kn., 3127.9nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 53353,
#   'rank': '21',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859561000.0,
#   'trackdistance': '329.597',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3127.8697213165',
#   'track': [[-30.317, 153.7722],
#    [-30.5274, 153.8053],
#    [-31.2004, 153.933],
#    [-31.6732, 154.0189],
#    [-31.6401, 153.9245],
#    [-31.6867, 153.5825],
#    [-32.0258, 153.5642],
#    [-32.34, 153.697],
#    [-32.6007, 153.7303],
#    [-32.6613, 153.4497],
#    [-32.611, 153.021],
#    [-33.3305, 152.71],
#    [-33.5691, 152.5955],
#    [-33.442, 152.1514],
#    [-33.6009, 151.8832],
#    [-33.8816, 151.3733]]},
#  'Shkiper-ANNA': {'heading': 188,
#   'lat_dec': -33.0469,
#   'lon_dec': 152.3587,
#   'lastreport_heading': '188',
#   'lastreport_speed': '0.9',
#   'sail': '252471',
#   'status': None,
#   'wind': '227°, 1.1kn.',
#   'ubtname': 'ANNA',
#   'usrname': 'Shkiper',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S33°2.814' E152°21.525', Hdg: 188°, Spd: 0.9kn., 3208.1nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 61161,
#   'rank': '28',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859588000.0,
#   'trackdistance': '86.755',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3208.07386465767',
#   'track': [[-33.0469, 152.3587],
#    [-32.945, 152.204],
#    [-33.2079, 151.7768],
#    [-33.7007, 151.3527],
#    [-33.8314, 151.3055],
#    [-33.8595, 151.1986]]},
#  'brinn-SEMSTIX': {'heading': 344,
#   'lat_dec': -30.1592,
#   'lon_dec': 153.5227,
#   'lastreport_heading': '344',
#   'lastreport_speed': '5.5',
#   'sail': '252483',
#   'status': None,
#   'wind': '22°, 15.3kn.',
#   'ubtname': 'SEMSTIX',
#   'usrname': 'brinn',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°9.549' E153°31.36', Hdg: 344°, Spd: 5.5kn., 3112.2nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 61130,
#   'rank': '17',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859546000.0,
#   'trackdistance': '280.613',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3112.22944323558',
#   'track': [[-30.1592, 153.5227],
#    [-30.482, 153.5921],
#    [-30.7694, 153.5594],
#    [-31.1274, 153.6006],
#    [-31.2873, 153.6379],
#    [-31.6151, 153.5032],
#    [-31.8958, 153.3456],
#    [-32.1599, 153.3435],
#    [-32.3959, 153.4357],
#    [-32.4524, 153.1804],
#    [-32.4629, 152.8853],
#    [-33.0035, 152.4424],
#    [-33.136, 152.2449],
#    [-33.3501, 152.0534],
#    [-33.339, 151.8568],
#    [-33.7426, 151.3309]]},
#  'Jarlei-My boat': {'heading': 69,
#   'lat_dec': -33.8595,
#   'lon_dec': 151.1988,
#   'lastreport_heading': '69',
#   'lastreport_speed': '0',
#   'sail': '253191',
#   'status': None,
#   'wind': '189°, 23.2kn.',
#   'ubtname': 'My boat',
#   'usrname': 'Jarlei',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S33°51.567' E151°11.929', Hdg: 69°, Spd: 0kn., 0.1nm. to mark 1/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 61415,
#   'rank': '32',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672593209000.0,
#   'trackdistance': '0.010',
#   'points': '0',
#   'nextmarknr': '1',
#   'distancetonextmark': '0.117826622837808',
#   'track': [[-33.8595, 151.1988], [-33.8595, 151.1986]]},
#  'FlyingFish-The Explorer': {'heading': 352,
#   'lat_dec': -30.6752,
#   'lon_dec': 154.4657,
#   'lastreport_heading': '352',
#   'lastreport_speed': '5.2',
#   'sail': '253255',
#   'status': None,
#   'wind': '37°, 12.1kn.',
#   'ubtname': 'The Explorer',
#   'usrname': 'FlyingFish',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°40.515' E154°27.944', Hdg: 352°, Spd: 5.2kn., 3167.7nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 61384,
#   'rank': '25',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859576000.0,
#   'trackdistance': '273.946',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3167.70131185186',
#   'track': [[-30.6752, 154.4657],
#    [-30.9862, 154.5355],
#    [-31.4931, 154.3212],
#    [-31.8432, 154.1339],
#    [-31.9238, 154.0904],
#    [-32.3385, 153.856],
#    [-32.4215, 153.6122],
#    [-32.5539, 153.4393],
#    [-32.6764, 153.3014],
#    [-32.7168, 152.9495],
#    [-32.8373, 152.7332],
#    [-33.2559, 152.1727],
#    [-33.4246, 152.0068],
#    [-33.5148, 151.6983],
#    [-33.493, 151.4353],
#    [-33.807, 151.3087]]},
#  'Salty_Welshman-Belle of the Ballast': {'heading': 5,
#   'lat_dec': -29.1569,
#   'lon_dec': 153.4448,
#   'lastreport_heading': '5',
#   'lastreport_speed': '0',
#   'sail': '253327',
#   'status': None,
#   'wind': '44°, 9.4kn.',
#   'ubtname': 'Belle of the Ballast',
#   'usrname': 'Salty_Welshman',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°9.416' E153°26.687', Hdg: 5°, Spd: 0kn., 3064.2nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 43910,
#   'rank': '7',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672845110000.0,
#   'trackdistance': '342.901',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3064.18689059143',
#   'track': [[-29.1569, 153.4448],
#    [-29.8029, 153.4337],
#    [-30.4003, 153.4807],
#    [-30.5463, 153.4144],
#    [-30.9705, 153.3653],
#    [-31.3084, 153.3433],
#    [-31.5757, 153.3582],
#    [-31.7901, 153.4512],
#    [-31.8849, 153.2871],
#    [-31.9323, 152.8983],
#    [-32.7514, 152.5337],
#    [-33.0714, 152.469],
#    [-33.1247, 152.1675],
#    [-33.0885, 151.7288],
#    [-33.7381, 151.3321]]},
#  'Gary B-KetchUp': {'heading': 41,
#   'lat_dec': -28.6325,
#   'lon_dec': 153.7303,
#   'lastreport_heading': '41',
#   'lastreport_speed': '5.1',
#   'sail': '253334',
#   'status': None,
#   'wind': '356°, 16.5kn.',
#   'ubtname': 'KetchUp',
#   'usrname': 'Gary B',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S28°37.952' E153°43.815', Hdg: 41°, Spd: 5.1kn., 3050.6nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 18533,
#   'rank': '2',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859488000.0,
#   'trackdistance': '348.342',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3050.58855813197',
#   'track': [[-28.6325, 153.7303],
#    [-28.9674, 153.6548],
#    [-29.5936, 153.5343],
#    [-30.1474, 153.5483],
#    [-30.3204, 153.3503],
#    [-30.7277, 153.3151],
#    [-31.0393, 153.2184],
#    [-31.3061, 153.1943],
#    [-31.4994, 153.1849],
#    [-31.6463, 152.9722],
#    [-31.7671, 152.887],
#    [-32.5831, 152.5269],
#    [-32.9426, 152.4295],
#    [-33.1754, 152.2151],
#    [-33.2361, 151.8842],
#    [-33.7292, 151.3654]]},
#  'Cap. Kiera-NUVOLA IV': {'finishtime': '-',
#   'sail': '253347',
#   'status': 'Abandoned race',
#   'wind': None,
#   'ubtname': 'NUVOLA IV',
#   'usrname': 'Cap. Kiera',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': '-',
#   'finished': 'true',
#   'teaname': None,
#   'usrnr': 61370,
#   'rank': 'DNF',
#   'btptype': "45' Ketch",
#   'racing': 0,
#   'timestamp': 1672611210000.0,
#   'trackdistance': '0.000',
#   'points': '0',
#   'nextmarknr': None,
#   'distancetonextmark': '3209.96601387568',
#   'track': []},
#  'Viper Vit-Petsamo': {'heading': 0,
#   'lat_dec': -29.169,
#   'lon_dec': 153.7169,
#   'lastreport_heading': '0',
#   'lastreport_speed': '5.3',
#   'sail': '253392',
#   'status': None,
#   'wind': '45°, 12.7kn.',
#   'ubtname': 'Petsamo',
#   'usrname': 'Viper Vit',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°10.14' E153°43.012', Hdg: 0°, Spd: 5.3kn., 3074.2nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 59528,
#   'rank': '11',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859524000.0,
#   'trackdistance': '344.873',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3074.16759726764',
#   'track': [[-29.169, 153.7169],
#    [-29.3966, 153.6295],
#    [-30.0981, 153.6601],
#    [-30.5804, 153.7163],
#    [-30.7102, 153.6846],
#    [-31.2025, 153.6894],
#    [-31.553, 153.6067],
#    [-31.8249, 153.5687],
#    [-31.9825, 153.5311],
#    [-32.0573, 153.2082],
#    [-32.1097, 152.8282],
#    [-32.8147, 152.4267],
#    [-32.9422, 152.2165],
#    [-33.2838, 152.1145],
#    [-33.6843, 152.0237],
#    [-33.8319, 151.3993]]},
#  'crit99-My boat': {'heading': 340,
#   'lat_dec': -29.0293,
#   'lon_dec': 153.5744,
#   'lastreport_heading': '340',
#   'lastreport_speed': '5',
#   'sail': '253444',
#   'status': None,
#   'wind': '31°, 8.8kn.',
#   'ubtname': 'My boat',
#   'usrname': 'crit99',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°1.759' E153°34.461', Hdg: 340°, Spd: 5kn., 3062.9nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 45576,
#   'rank': '5',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859498000.0,
#   'trackdistance': '392.325',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3062.93147025008',
#   'track': [[-29.0293, 153.5744],
#    [-29.413, 153.6332],
#    [-30.1577, 153.753],
#    [-30.8018, 153.8923],
#    [-30.9855, 153.9288],
#    [-31.49, 153.8784],
#    [-31.7651, 153.691],
#    [-32.0241, 153.6216],
#    [-32.1369, 153.5108],
#    [-32.1824, 153.1429],
#    [-32.2136, 152.7264],
#    [-33.0818, 152.5501],
#    [-33.4255, 152.5604],
#    [-33.8188, 152.5347],
#    [-34.0563, 152.2745],
#    [-33.8906, 151.4307]]},
#  'Djon-NORD': {'heading': 73,
#   'lat_dec': -29.5522,
#   'lon_dec': 154.5706,
#   'lastreport_heading': '73',
#   'lastreport_speed': '4.5',
#   'sail': '253449',
#   'status': None,
#   'wind': '30°, 8.7kn.',
#   'ubtname': 'NORD',
#   'usrname': 'Djon',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S29°33.133' E154°34.235', Hdg: 73°, Spd: 4.5kn., 3121.1nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 54382,
#   'rank': '19',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859553000.0,
#   'trackdistance': '363.727',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3121.12145187538',
#   'track': [[-29.5522, 154.5706],
#    [-29.6135, 154.1723],
#    [-29.6681, 153.3819],
#    [-30.2674, 153.296],
#    [-30.4057, 153.4759],
#    [-30.8817, 153.5716],
#    [-31.1619, 153.4114],
#    [-31.3964, 153.3793],
#    [-31.5744, 153.4297],
#    [-31.6951, 153.1462],
#    [-31.849, 153.0881],
#    [-32.5837, 152.5342],
#    [-32.9404, 152.4457],
#    [-32.9988, 152.1175],
#    [-33.1238, 151.7814],
#    [-33.7815, 151.3764]]},
#  'OldSillyRic-Esquechi Original': {'heading': 20,
#   'lat_dec': -32.4451,
#   'lon_dec': 158.6925,
#   'lastreport_heading': '20',
#   'lastreport_speed': '6',
#   'sail': '253458',
#   'status': None,
#   'wind': '245°, 11.5kn.',
#   'ubtname': 'Esquechi Original',
#   'usrname': 'OldSillyRic',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S32°26.708' E158°41.551', Hdg: 20°, Spd: 6kn., 3393.1nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 38909,
#   'rank': '31',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672859599000.0,
#   'trackdistance': '466.492',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3393.07439628127',
#   'track': [[-32.4451, 158.6925],
#    [-32.7309, 158.4594],
#    [-33.3732, 157.9484],
#    [-34.1671, 157.3148],
#    [-34.4623, 156.882],
#    [-34.803, 156.1542],
#    [-34.7709, 155.7035],
#    [-34.8028, 155.3501],
#    [-34.59, 155.0238],
#    [-34.4556, 154.5498],
#    [-34.2807, 154.0118],
#    [-33.7223, 152.5894],
#    [-33.5722, 152.1232],
#    [-33.6645, 151.8896],
#    [-33.5104, 151.5765],
#    [-33.833, 151.2804]]}}

# %%
data=[(boats[boat]['ubtname'],
       boats[boat]['lat_dec'],
       boats[boat]['lon_dec'],
       boats[boat]['rank'])
      for boat in list(boats.keys()) if 'lat_dec' in boats[boat]]

# %%
df=pd.DataFrame(data, columns=['Boat', 'Lat', 'Lon', 'Rank'])
df['Rank']=df['Rank'].astype('int64')
df.sort_values('Rank', ascending=True, inplace=True)
df.reset_index(inplace=True)
# Out:
#     index                           Boat      Lat       Lon  Rank
# 0       0                  Voyage Voyage -28.6192  153.7223     1
# 1      27                        KetchUp -28.6325  153.7303     2
# 2      15                       STELLA\t -28.8521  153.7455     3
# 3       5                      SpaceShip -29.0054  153.5847     4
# 4      29                        My boat -29.0293  153.5744     5
# 5      11                      Celephais -28.9901  153.6602     6
# 6      26           Belle of the Ballast -29.1569  153.4448     7
# 7      13                 SS CARTAGENA\n -28.9847  153.7362     8
# 8       7                        Lizzy\n -29.0666  153.6613     9
# 9      16                       Yoyodyne -29.1095  153.7008    10
# 10     28                        Petsamo -29.1690  153.7169    11
# 11     14                        My boat -29.1909  153.8754    12
# 12     20                          PssP2 -29.3457  153.7297    13
# 13      6                        Slowdog -29.2841  153.8280    14
# 14      8               PtitGuy Ketch II -29.6915  153.6237    15
# 15      1                     Guppy-Maru -29.4933  154.1416    16
# 16     23                        SEMSTIX -30.1592  153.5227    17
# 17     19                   Ketchy Pride -30.4582  153.3441    18
# 18     30                           NORD -29.5522  154.5706    19
# 19     10  Miguel Domenech Martinez   MD -29.9544  154.0879    20
# 20     21                           HERA -30.3170  153.7722    21
# 21     12                    Black sheep -30.3708  153.8111    22
# 22      9                          gypsy -30.6408  154.2634    23
# 23     17   T E Q U I L A  S U N R I S E -30.7376  154.2041    24
# 24     25                   The Explorer -30.6752  154.4657    25
# 25      2                       Lisa Ann -30.7085  154.7831    26
# 26      4                        My boat -31.5317  153.6971    27
# 27     22                           ANNA -33.0469  152.3587    28
# 28      3                        Ketch I -37.0438  150.3001    29
# 29     18                            NBK -39.3215  147.0170    30
# 30     31              Esquechi Original -32.4451  158.6925    31
# 31     24                        My boat -33.8595  151.1988    32

# %%
colors=['red', 'blue', 'green', 'purple', 'orange', 'darkred', 'lightred', 'beige', 'darkblue', 'darkgreen', 'cadetblue', 'darkpurple', 'white', 'pink', 'lightblue', 'lightgreen', 'gray', 'black', 'lightgray']

# %%
center=(df.loc[0, 'Lat'], df.loc[0, 'Lon'])
mymap=folium.Map(location=center, zoom_start=7)
for idx in df.index:
    lat=df.loc[idx, 'Lat']
    lon=df.loc[idx, 'Lon']
    name=df.loc[idx, 'Boat'].upper()
    rank=df.loc[idx, 'Rank']
    if idx < len(colors):
        color=colors[idx]
    else:
        color='black'
    popup=str(lat) + ', ' + str(lon)
    folium.Marker([lat, lon], popup=name + ' ' + str(rank), icon=folium.Icon(color=color, icon='home')).add_to(mymap)

# %%
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50e9fab674b91e9bfdafdb959eac95d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50e9fab674b91e9bfdafdb959eac95d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50e9fab674b91e9bfdafdb959eac95d3 = L.map(
#                 &quot;map_50e9fab674b91e9bfdafdb959eac95d3&quot;,
#                 {
#                     center: [-28.6192, 153.7223],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5baf6ed534717a3e059f47055617e8d2 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_50e9fab674b91e9bfdafdb959eac95d3);
#
#
#             var marker_ad886b5fd25272dca404cd4da0cce463 = L.marker(
#                 [-28.6192, 153.7223],
#                 {}
#             ).addTo(map_50e9fab674b91e9bfdafdb959eac95d3);
#
#
#             var icon_800cb2d6ec2d83bc95342d2634d32570 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ad886b5fd25272dca404cd4da0cce463.setIcon(icon_800cb2d6ec2d83bc95342d2634d32570);
#
#
#         var popup_af2dd724208db3cc6581b044719c9ea1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d3ce510a5ec5f845dae7cbf406ac8be = $(`&lt;div id=&quot;html_8d3ce510a5ec5f845dae7cbf406ac8be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;VOYAGE VOYAGE 1&lt;/div&gt;`)[0];
#                 popup_af2dd724208db3cc6581b044719c9ea1.setContent(html_8d3ce510a5ec5f845dae7cbf406ac8be);
#
#
#
#         marker_ad886b5fd25272dca404cd4da0cce463.bindPopup(popup_af2dd724208db3cc6581b044719c9ea1)
#         ;
#
#
#
#
#             var marker_83dd98648df8460f45ae4b7a1cde7c22 = L.marker(
#                 [-28.6325, 153.7303],
#                 {}
#             ).addTo(map_50e9fab674b91e9bfdafdb959eac95d3);
#
#
#             var icon_9e3b13b2486ae4f3bcb4672a502e1b94 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_83dd98648df8460f45ae4b7a1cde7c22.setIcon(icon_9e3b13b2486ae4f3bcb4672a502e1b94);
#
#
#         var popup_af358ae10525029d6418ae06d02a84a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_780879d78e22e2dd01a232903e32851f = $(`&lt;div id=&quot;html_780879d78e22e2dd01a232903e32851f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;KETCHUP 2&lt;/div&gt;`)[0];
#                 popup_af358ae10525029d6418ae06d02a84a2.setContent(html_780879d78e22e2dd01a232903e32851f);
#
#
#
#         marker_83dd98648df8460f45ae4b7a1cde7c22.bindPopup(popup_af358ae10525029d6418ae06d02a84a2)
#         ;
#
#
#
#
#             var marker_150ecf998a1d7e35d6124883b578a4ef = L.marker(
#                 [-28.8521, 153.7455],
#                 {}
#             ).addTo(map_50e9fab674b91e9bfdafdb959eac95d3);
#
#
#             var icon_6694933b625ceb2a5a9d3e27f81c6944 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_150ecf998a1d7e35d6124883b578a4ef.setIcon(icon_6694933b625ceb2a5a9d3e27f81c6944);
#
#
#         var popup_8f3b0b695aa5fa04b0a345c341972858 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_816c98e994608c6b3a20ea0f707328e2 = $(`&lt;div id=&quot;html_816c98e994608c6b3a20ea0f707328e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;STELLA	 3&lt;/div&gt;`)[0];
#                 popup_8f3b0b695aa5fa04b0a345c341972858.setContent(html_816c98e994608c6b3a20ea0f707328e2);
#
#
#
#         marker_150ecf998a1d7e35d6124883b578a4ef.bindPopup(popup_8f3b0b695aa5fa04b0a345c341972858)
#         ;
#
#
#
#
#             var marker_76b3c7dd1234d2427ce339047f28ba20 = L.marker(
#                 [-29.0054, 153.5847],
#                 {}
#             ).addTo(map_50e9fab674b91e9bfdafdb959eac95d3);
#
#
#             var icon_d2aa9312c409d69aaedcd660a74e252d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;:

# %%
mymap.save(html)

# %%
import random
icon_color = ["#"+''.join([random.choice('ABCDEF0123456789') for i in range(6)])]
icon = folium.Icon(icon="globe", icon_color=icon_color, color="lightgreen", prefix="fa")

# %%
icon_color
# Out:
# ['#67B3E4']
