# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
from boats.lib.common import *
from boats.lib.boat import Boat

# %%
boatname = 'Petsamo'

sails = ['Nr.1', 'Nr.2', 'Nr.3', 'Stormjib', 'Mainsail', 'Genaker', 'Mizzen', 'Mizzen staysail']
points_of_sail={
    'close haul': list(range(0,37)),
    'close reach': list(range(36,73)),
    'beam': list(range(72,109)),
    'broad reach': list(range(108,145)),
    'run': list(range(144,181))
}
yesmark = 'x'
nomark = '-'

# %%
df=Boat(boatname).get_logged_data()
#df.dropna(inplace=True)
df['heel']=df['heel'].apply(lambda x: int(abs(x)))
df['twa']=df['twa'].apply(lambda x: abs(x))
df=df[df['spd']!=0]
df['spd / tws']=round(df['spd']/df['tws'],2)
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#    tws  spd  twd  twa  heel  \
# 0  5.8  2.7  110  174     6
# 1  5.8  2.6  110  175     6
# 2  5.8  2.6  110  175     6
# 3  5.8  2.6  110  177     6
# 4  5.8  2.6  110  177     6
#
#                                                sails  lat  lon  awa  spd / tws
# 0  [Mainsail, Mizzen, Genaker, Mizzen staysail, N...  NaN  NaN  NaN       0.47
# 1  [Mainsail, Mizzen, Genaker, Mizzen staysail, N...  NaN  NaN  NaN       0.45
# 2  [Mainsail, Mizzen, Genaker, Mizzen staysail, N...  NaN  NaN  NaN       0.45
# 3  [Mainsail, Mizzen, Genaker, Mizzen staysail, N...  NaN  NaN  NaN       0.45
# 4  [Mainsail, Mizzen, Genaker, Mizzen staysail, N...  NaN  NaN  NaN       0.45

# %%
len(df)
# Out:
# 71

# %% [markdown]
# #### Expand sail data:

# %%
for i in range(len(df.index)):
    for sail in sails:
        if sail in df.iloc[i]['sails']:
            mark = yesmark
        else:
            mark = nomark
        df.at[i, sail] = mark
        
df.drop(['sails'], axis=1, inplace=True)
df.head()
# Out:
#    tws  spd  twd  twa  heel  lat  lon  awa  spd / tws Nr.1 Nr.2 Nr.3 Stormjib  \
# 0  5.8  2.7  110  174     6  NaN  NaN  NaN       0.47    -    -    x        -
# 1  5.8  2.6  110  175     6  NaN  NaN  NaN       0.45    -    -    x        -
# 2  5.8  2.6  110  175     6  NaN  NaN  NaN       0.45    -    -    x        -
# 3  5.8  2.6  110  177     6  NaN  NaN  NaN       0.45    -    -    x        -
# 4  5.8  2.6  110  177     6  NaN  NaN  NaN       0.45    -    -    x        -
#
#   Mainsail Genaker Mizzen Mizzen staysail
# 0        x       x      x               x
# 1        x       x      x               x
# 2        x       x      x               x
# 3        x       x      x               x
# 4        x       x      x               x

# %%
df['pos']=[name for i in range(len(df.index)-1) for name in points_of_sail if df.iloc[i]['twa'] in points_of_sail[name]]

# %%
df_plot=df[['pos', 'spd']].groupby('pos').mean().sort_values('pos')
sns.barplot(data=df_plot, x=df_plot.index, y='spd').set(title='Speed by point of sale')
# Out:
# [Text(0.5, 1.0, 'Speed by point of sale')]

# %%
sns.countplot(data=df.sort_values('pos'), x='pos').set(title='Points of sail frequency')
# Out:
# [Text(0.5, 1.0, 'Points of sail frequency')]

# %%
df_plot=df[['heel', 'spd']].groupby('heel').mean()
sns.lineplot(data=df_plot, x=df_plot.index, y='spd').set(title='Speed by heel')
# Out:
# [Text(0.5, 1.0, 'Speed by heel')]

# %%
sns.regplot(data=df, x='tws', y='spd').set(title='spd to tws')
# Out:
# [Text(0.5, 1.0, 'spd to tws')]

# %%
sns.lmplot(data=df, x='tws', y='heel').set(title='heel by tws')

# %%
sns.lmplot(data=df, x='tws', y='spd / tws').set(title='Speed efficiency to tws')

# %%
df_pos=df.sort_values('twa')[['pos'] + sails].reset_index(drop=True)
df_pos
# Out:
#             pos Nr.1 Nr.2 Nr.3 Stormjib Mainsail Genaker Mizzen  \
# 0   close reach    -    x    -        -        x       -      x
# 1   close reach    -    x    -        -        x       -      x
# 2   close reach    -    -    x        -        x       -      -
# 3   close reach    -    x    -        -        x       -      x
# 4   close reach    -    x    -        -        x       -      x
# ..          ...  ...  ...  ...      ...      ...     ...    ...
# 66          run    -    -    x        -        x       x      x
# 67          run    -    -    x        -        x       x      x
# 68          run    -    -    x        -        x       x      x
# 69          run    -    -    x        -        x       x      x
# 70          run    -    -    x        -        x       x      x
#
#    Mizzen staysail
# 0                -
# 1                -
# 2                -
# 3                -
# 4                -
# ..             ...
# 66               x
# 67               x
# 68               x
# 69               x
# 70               x
#
# [71 rows x 9 columns]

# %%
df_pos=df_pos.replace(yesmark, 1)
df_pos=df_pos.replace(nomark, 0)
df_pos
# Out:
#             pos  Nr.1  Nr.2  Nr.3  Stormjib  Mainsail  Genaker  Mizzen  \
# 0   close reach     0     1     0         0         1        0       1
# 1   close reach     0     1     0         0         1        0       1
# 2   close reach     0     0     1         0         1        0       0
# 3   close reach     0     1     0         0         1        0       1
# 4   close reach     0     1     0         0         1        0       1
# ..          ...   ...   ...   ...       ...       ...      ...     ...
# 66          run     0     0     1         0         1        1       1
# 67          run     0     0     1         0         1        1       1
# 68          run     0     0     1         0         1        1       1
# 69          run     0     0     1         0         1        1       1
# 70          run     0     0     1         0         1        1       1
#
#     Mizzen staysail
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 66                1
# 67                1
# 68                1
# 69                1
# 70                1
#
# [71 rows x 9 columns]

# %%
df_plot=df_pos.groupby('pos').sum()
df_plot
# Out:
#              Nr.1  Nr.2  Nr.3  Stormjib  Mainsail  Genaker  Mizzen  \
# pos
# beam           17     5    11         0        22        0      22
# broad reach     3     3    10         0        10        4      10
# close reach     4    14     4         0        21        0      20
# run             2     5    17         0        18       11      18
#
#              Mizzen staysail
# pos
# beam                       0
# broad reach                7
# close reach                1
# run                       15

# %%
sns.heatmap(df_plot).set(title='Sail types usage by point of sail')
# Out:
# [Text(0.5, 1.0, 'Sail types usage by point of sail')]

# %%
for sail in sails:
    sns.lmplot(data=df, x='tws', y='spd', hue=sail).set(title='spd to tws by sail')
