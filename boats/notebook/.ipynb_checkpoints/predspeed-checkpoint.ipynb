# %% [markdown]
# Predict speed based on TWD and TWS

# %%
import pandas as pd
import numpy as np
import sklearn
import seaborn as sns
from sklearn.linear_model import RidgeCV, LassoCV, ElasticNetCV, LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
import pickle
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

import sys

sys.path.append('/Users/hedge/PyCharmProjects')

from boats.lib.common import *
from boats.lib.boat import Boat

# %%
df=Boat('Petsamo').get_logged_data()
df.reset_index(drop=True, inplace=True)
df['twa']=df['twa'].apply(lambda x: abs(x))
df=df[df['spd']!=0]
df.dropna(inplace=True)
df.tail()
# Out:
#        tws  spd  twd  twa  awa  heel       lat       lon  \
# 1407  16.4  6.0   73  100  -78    34 -16.80350 -29.07616
# 1408  16.0  5.7   75   98  -77    34 -17.08110 -29.07923
# 1409  12.5  5.1   90   83  -62    25 -17.33272 -29.07741
# 1410  13.0  5.3   87   86  -64    27 -17.47210 -29.07363
# 1411  13.5  6.7   87   91  -65    33 -17.48198 -29.07363
#
#                                           sails    hdg
# 1407                   [Mainsail, Mizzen, Nr.1]  173.0
# 1408                   [Mainsail, Mizzen, Nr.1]  173.0
# 1409                   [Mainsail, Mizzen, Nr.1]  173.0
# 1410                   [Mainsail, Mizzen, Nr.1]  173.0
# 1411  [Mainsail, Mizzen, Mizzen staysail, Nr.1]  178.0

# %%
len(df)
# Out:
# 909

# %%
estimators=[('ridgecv', RidgeCV()), ('lassocv', LassoCV()), ('lr', LinearRegression()), ('elasticcv', ElasticNetCV())]

# %%
X=df[['tws', 'twd', 'hdg']]
y=df['spd']

# %%
scores = []
for estimator in estimators:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.005, random_state=42) 
    for degree in range(10):
        pipe = make_pipeline(PolynomialFeatures(degree=degree), estimator[1])
        pipe.fit(X_train, y_train)
        scores.append( (estimator[0], degree, pipe.score(X_test, y_test)) )
# Out:
# /opt/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_ridge.py:2149: RuntimeWarning: invalid value encountered in divide
#   squared_errors = (c / G_inverse_diag) ** 2

# %%
df_scores = pd.DataFrame(scores, columns=['Estimator', 'Degree', 'Score'])
df_scores.set_index('Estimator', inplace=True)
df_scores.groupby('Estimator').max()
# Out:
#            Degree     Score
# Estimator
# elasticcv       9  0.603977
# lassocv         9  0.603979
# lr              9  0.835660
# ridgecv         9  0.691809

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.005, random_state=42) 
pipe=make_pipeline(PolynomialFeatures(degree=7), LinearRegression()).fit(X_train, y_train)
yhat=pipe.predict(X)
print(round(pipe.score(X, y),2))
# Out:
# 0.74

# %%
df_lr=X.copy()
df_lr['Predicted']=[round(yhat[i],1) for i in range(len(yhat))]
df_lr['Actual']=y
df_lr
# Out:
#        tws  twd    hdg  Predicted  Actual
# 495    9.2   85   28.0        5.7     5.5
# 497    8.4   88   28.0        5.1     5.3
# 498    8.7   92   28.0        5.3     5.4
# 499    8.2   87   28.0        5.0     5.2
# 500    7.6   83   28.0        4.5     4.5
# ...    ...  ...    ...        ...     ...
# 1407  16.4   73  173.0        5.3     6.0
# 1408  16.0   75  173.0        5.3     5.7
# 1409  12.5   90  173.0        5.7     5.1
# 1410  13.0   87  173.0        5.6     5.3
# 1411  13.5   87  178.0        5.5     6.7
#
# [909 rows x 5 columns]

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
# Epoch 65/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5598 - val_loss: 0.7052
# Epoch 66/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3455 - val_loss: 0.5298
# Epoch 67/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2563 - val_loss: 0.6306
# Epoch 68/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3462 - val_loss: 0.7658
# Epoch 69/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3813 - val_loss: 0.5975
# Epoch 70/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2889 - val_loss: 0.6453
# Epoch 71/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5691 - val_loss: 0.6448
# Epoch 72/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2155 - val_loss: 0.8273
# Epoch 73/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3764 - val_loss: 0.6033
# Epoch 74/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3892 - val_loss: 0.5539
# Epoch 75/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1639 - val_loss: 0.5860
# Epoch 76/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2078 - val_loss: 0.5527
# Epoch 77/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3200 - val_loss: 0.6237
# Epoch 78/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2828 - val_loss: 0.6036
# Epoch 79/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5123 - val_loss: 0.4938
# Epoch 80/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0963 - val_loss: 0.8998
# Epoch 81/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2971 - val_loss: 0.6214
# Epoch 82/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4875 - val_loss: 0.5007
# Epoch 83/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3810 - val_loss: 0.6323
# Epoch 84/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3925 - val_loss: 0.4833
# Epoch 85/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3185 - val_loss: 0.5584
# Epoch 86/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1489 - val_loss: 0.9109
# Epoch 87/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2838 - val_loss: 0.7903
# Epoch 88/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2745 - val_loss: 0.5604
# Epoch 89/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2403 - val_loss: 0.5026
# Epoch 90/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2611 - val_loss: 0.9562
# Epoch 91/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3156 - val_loss: 0.5057
# Epoch 92/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4655 - val_loss: 0.7394
# Epoch 93/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3552 - val_loss: 0.4981
# Epoch 94/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4112 - val_loss: 0.5769
# Epoch 95/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5089 - val_loss: 0.4855
# Epoch 96/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2563 - val_loss: 0.5260
# Epoch 97/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2544 - val_loss: 0.6871
# Epoch 98/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3387 - val_loss: 0.4943
# Epoch 99/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0881 - val_loss: 1.3531
# Epoch 100/100
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6994 - val_loss: 0.6419
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step

# %%
df_kr=predictors.copy()
df_kr['Predicted']=[round(yhat[i][0],1) for i in range(len(yhat))]
df_kr['Actual']=target
df_kr
# Out:
#        tws  twd    hdg  Predicted  Actual
# 495    9.2   85   28.0        5.1     5.5
# 497    8.4   88   28.0        5.0     5.3
# 498    8.7   92   28.0        5.2     5.4
# 499    8.2   87   28.0        4.9     5.2
# 500    7.6   83   28.0        4.5     4.5
# ...    ...  ...    ...        ...     ...
# 1407  16.4   73  173.0        4.8     6.0
# 1408  16.0   75  173.0        4.8     5.7
# 1409  12.5   90  173.0        5.1     5.1
# 1410  13.0   87  173.0        5.0     5.3
# 1411  13.5   87  178.0        5.0     6.7
#
# [909 rows x 5 columns]

# %%
sns.scatterplot(df_lr.copy()[['Predicted', 'Actual', 'tws']].set_index('tws')).set_title('LR')
# Out:
# Text(0.5, 1.0, 'LR')

# %%
sns.scatterplot(df_kr.copy()[['Predicted', 'Actual', 'tws']].set_index('tws')).set_title('Keras')
# Out:
# Text(0.5, 1.0, 'Keras')

# %%
sns.regplot(df_lr, x='tws', y='Actual')
# Out:
# <Axes: xlabel='tws', ylabel='Actual'>

# %%
sns.regplot(df_lr, x='tws', y='Predicted')
# Out:
# <Axes: xlabel='tws', ylabel='Predicted'>

# %%
tws=15
twd=105
hdg=177
data=pd.DataFrame([[tws, twd, hdg]])

# %%
round(pipe.predict(data)[0],1)
# Out:
# 5.4

# %%
round(model.predict(data)[0][0],1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 5.8
