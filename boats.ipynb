# %%
import requests
import json
import pandas as pd

url='https://sarl.ingenium.net.au/racelog?racenr=38602'
res=requests.get(url)
me='VIPER VIT'

# %%
boats = res.json()['result']

# %%
boats
# Out:
# {'Encelade-Voyage Voyage': {'heading': 5,
#   'lat_dec': -30.7883,
#   'lon_dec': 153.5554,
#   'lastreport_heading': '5',
#   'lastreport_speed': '4.9',
#   'sail': '117873',
#   'status': None,
#   'wind': '67°, 7.6kn.',
#   'ubtname': 'Voyage Voyage',
#   'usrname': 'Encelade',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°47.295' E153°33.323', Hdg: 5°, Spd: 4.9kn., 3142nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 21144,
#   'rank': '4',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744300000.0,
#   'trackdistance': '231.990',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3141.9713917361',
#   'track': [[-30.7883, 153.5554],
#    [-31.1288, 153.4828],
#    [-31.388, 153.4828],
#    [-31.509, 153.4467],
#    [-31.6306, 153.1994],
#    [-31.7385, 152.8927],
#    [-32.5503, 152.6125],
#    [-32.8815, 152.5129],
#    [-32.9086, 152.1299],
#    [-33.0168, 151.789],
#    [-33.7324, 151.3701]]},
#  'dark one77-Guppy-Maru': {'heading': 31,
#   'lat_dec': -31.4208,
#   'lon_dec': 153.7892,
#   'lastreport_heading': '31',
#   'lastreport_speed': '4.8',
#   'sail': '118246',
#   'status': None,
#   'wind': '76°, 8.9kn.',
#   'ubtname': 'Guppy-Maru',
#   'usrname': 'dark one77',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°25.245' E153°47.35', Hdg: 31°, Spd: 4.8kn., 3178.7nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 20851,
#   'rank': '15',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744341000.0,
#   'trackdistance': '204.352',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3178.6503731477',
#   'track': [[-31.4208, 153.7892],
#    [-31.6901, 153.5971],
#    [-31.899, 153.4846],
#    [-32.0007, 153.3988],
#    [-32.1047, 153.1245],
#    [-32.1681, 152.735],
#    [-32.8937, 152.3941],
#    [-33.0368, 152.3175],
#    [-33.1634, 152.1983],
#    [-33.1628, 151.7987],
#    [-33.7639, 151.3407]]},
#  'FreeQuest-Lisa Ann': {'heading': 29,
#   'lat_dec': -31.6833,
#   'lon_dec': 153.7054,
#   'lastreport_heading': '29',
#   'lastreport_speed': '5.1',
#   'sail': '127111',
#   'status': None,
#   'wind': '74°, 9.9kn.',
#   'ubtname': 'Lisa Ann',
#   'usrname': 'FreeQuest',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°41' E153°42.325', Hdg: 29°, Spd: 5.1kn., 3187.9nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 31362,
#   'rank': '20',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744361000.0,
#   'trackdistance': '193.000',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3187.8871979433',
#   'track': [[-31.6833, 153.7054],
#    [-31.9374, 153.5175],
#    [-32.186, 153.4419],
#    [-32.4008, 153.4416],
#    [-32.5186, 153.2638],
#    [-32.752, 153.2677],
#    [-33.1115, 152.6142],
#    [-33.3998, 152.5628],
#    [-33.4632, 152.2863],
#    [-33.6346, 152.0428],
#    [-33.7546, 151.3763]]},
#  'Steiger-Ketch I': {'heading': 266,
#   'lat_dec': -35.4656,
#   'lon_dec': 152.2346,
#   'lastreport_heading': '266',
#   'lastreport_speed': '5.8',
#   'sail': '128434',
#   'status': None,
#   'wind': '43°, 10.7kn.',
#   'ubtname': 'Ketch I',
#   'usrname': 'Steiger',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S35°27.935' E152°14.077', Hdg: 266°, Spd: 5.8kn., 3319.3nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 20227,
#   'rank': '28',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744392000.0,
#   'trackdistance': '243.306',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3319.30833486108',
#   'track': [[-35.4656, 152.2346],
#    [-35.4912, 152.7237],
#    [-35.3289, 152.9371],
#    [-35.0628, 152.9664],
#    [-34.7794, 152.9715],
#    [-34.5312, 153.1709],
#    [-33.4752, 153.0601],
#    [-33.3657, 152.626],
#    [-33.3716, 152.2996],
#    [-33.4909, 152.0107],
#    [-33.7119, 151.3567]]},
#  'jerry2-My boat': {'heading': 6,
#   'lat_dec': -32.2322,
#   'lon_dec': 153.1654,
#   'lastreport_heading': '6',
#   'lastreport_speed': '5.3',
#   'sail': '129253',
#   'status': None,
#   'wind': '62°, 13.4kn.',
#   'ubtname': 'My boat',
#   'usrname': 'jerry2',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S32°13.93' E153°9.924', Hdg: 6°, Spd: 5.3kn., 3195.6nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 32686,
#   'rank': '22',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744369000.0,
#   'trackdistance': '184.716',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3195.55451071202',
#   'track': [[-32.2322, 153.1654],
#    [-32.5425, 153.182],
#    [-32.7174, 153.0837],
#    [-32.9251, 153.0584],
#    [-33.2284, 153.1968],
#    [-33.5923, 153.2609],
#    [-33.8895, 152.362],
#    [-33.8686, 151.9037],
#    [-33.7869, 151.4322],
#    [-33.7732, 151.3303]]},
#  'pd123-Pete': {'finishtime': '-',
#   'sail': '131603',
#   'status': 'Abandoned race',
#   'wind': None,
#   'ubtname': 'Pete',
#   'usrname': 'pd123',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': '-',
#   'finished': 'true',
#   'teaname': None,
#   'usrnr': 32002,
#   'rank': 'DNF',
#   'btptype': "45' Ketch",
#   'racing': 0,
#   'timestamp': 1672575246000.0,
#   'trackdistance': '0.000',
#   'points': '0',
#   'nextmarknr': None,
#   'distancetonextmark': '3211.69238827861',
#   'track': [[-33.8533, 151.2075]]},
#  'StormGirl-SpaceShip': {'heading': 9,
#   'lat_dec': -31.0262,
#   'lon_dec': 153.2916,
#   'lastreport_heading': '9',
#   'lastreport_speed': '5.2',
#   'sail': '153582',
#   'status': None,
#   'wind': '53°, 9.1kn.',
#   'ubtname': 'SpaceShip',
#   'usrname': 'StormGirl',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°1.57' E153°17.498', Hdg: 9°, Spd: 5.2kn., 3144.1nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 8791,
#   'rank': '6',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744307000.0,
#   'trackdistance': '205.162',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3144.05812930301',
#   'track': [[-31.0262, 153.2916],
#    [-31.3537, 153.2249],
#    [-31.6356, 153.2156],
#    [-31.759, 153.1118],
#    [-31.9559, 153.0637],
#    [-32.1247, 152.854],
#    [-32.8503, 152.4769],
#    [-33.1499, 152.4031],
#    [-33.3922, 152.2777],
#    [-33.5077, 151.9896],
#    [-33.8328, 151.4121]]},
#  'Kreole-Beagle II': {'finishtime': '-',
#   'sail': '157904',
#   'status': 'Abandoned race',
#   'wind': None,
#   'ubtname': 'Beagle II',
#   'usrname': 'Kreole',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': '-',
#   'finished': 'true',
#   'teaname': None,
#   'usrnr': 3900,
#   'rank': 'DNF',
#   'btptype': "45' Ketch",
#   'racing': 0,
#   'timestamp': 1672539203000.0,
#   'trackdistance': '0.000',
#   'points': '0',
#   'nextmarknr': None,
#   'distancetonextmark': '3844.10306278101',
#   'track': []},
#  'Chris66-Slowdog': {'heading': 17,
#   'lat_dec': -31.4587,
#   'lon_dec': 153.7252,
#   'lastreport_heading': '17',
#   'lastreport_speed': '5.4',
#   'sail': '160273',
#   'status': None,
#   'wind': '74°, 9.4kn.',
#   'ubtname': 'Slowdog',
#   'usrname': 'Chris66',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°27.52' E153°43.515', Hdg: 17°, Spd: 5.4kn., 3178.3nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 25805,
#   'rank': '14',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744338000.0,
#   'trackdistance': '203.238',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3178.25932052765',
#   'track': [[-31.4587, 153.7252],
#    [-31.8087, 153.6445],
#    [-32.0765, 153.5966],
#    [-32.2011, 153.5219],
#    [-32.221, 153.1356],
#    [-32.3105, 152.8288],
#    [-32.6552, 152.4605],
#    [-33.0119, 152.3681],
#    [-33.3346, 152.2549],
#    [-33.4728, 151.9779],
#    [-33.7795, 151.3825]]},
#  'Dbird64-Lizzy\n': {'heading': 352,
#   'lat_dec': -31.4577,
#   'lon_dec': 153.9825,
#   'lastreport_heading': '352',
#   'lastreport_speed': '5.5',
#   'sail': '165613',
#   'status': None,
#   'wind': '85°, 7.9kn.',
#   'ubtname': 'Lizzy\n',
#   'usrname': 'Dbird64',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°27.464' E153°58.952', Hdg: 352°, Spd: 5.5kn., 3186.8nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 6479,
#   'rank': '19',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744357000.0,
#   'trackdistance': '217.197',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3186.77808989661',
#   'track': [[-31.4577, 153.9825],
#    [-31.7933, 153.9368],
#    [-31.9846, 153.8005],
#    [-32.1924, 153.7853],
#    [-32.2731, 153.5373],
#    [-32.2773, 153.1572],
#    [-33.0082, 152.7984],
#    [-33.0204, 152.5109],
#    [-33.0431, 152.1535],
#    [-33.2029, 151.8543],
#    [-33.7445, 151.3745]]},
#  'PtitGuy-PtitGuy Ketch II': {'heading': 8,
#   'lat_dec': -31.4225,
#   'lon_dec': 153.2657,
#   'lastreport_heading': '8',
#   'lastreport_speed': '5.2',
#   'sail': '173699',
#   'status': None,
#   'wind': '53°, 10.3kn.',
#   'ubtname': 'PtitGuy Ketch II',
#   'usrname': 'PtitGuy',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°25.35' E153°15.944', Hdg: 8°, Spd: 5.2kn., 3161.4nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 14670,
#   'rank': '10',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744323000.0,
#   'trackdistance': '219.764',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3161.41700081493',
#   'track': [[-31.4225, 153.2657],
#    [-31.6668, 153.1557],
#    [-31.9333, 153.1369],
#    [-32.1198, 153.1143],
#    [-32.2794, 153.0042],
#    [-32.4963, 152.9701],
#    [-33.4451, 152.9346],
#    [-33.5144, 152.6129],
#    [-33.6592, 152.3852],
#    [-34.0263, 152.2528],
#    [-33.8826, 151.4315]]},
#  'Tony2-gypsy': {'heading': 123,
#   'lat_dec': -32.0575,
#   'lon_dec': 153.7925,
#   'lastreport_heading': '123',
#   'lastreport_speed': '5.1',
#   'sail': '181221',
#   'status': None,
#   'wind': '78°, 9.9kn.',
#   'ubtname': 'gypsy',
#   'usrname': 'Tony2',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S32°3.453' E153°47.551', Hdg: 123°, Spd: 5.1kn., 3207.9nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 40348,
#   'rank': '25',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744381000.0,
#   'trackdistance': '223.327',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3207.91124801814',
#   'track': [[-32.0575, 153.7925],
#    [-32.284, 153.5779],
#    [-32.3513, 153.3224],
#    [-32.3265, 152.9696],
#    [-32.5275, 152.9353],
#    [-32.8245, 153.0571],
#    [-33.6025, 152.8601],
#    [-33.4902, 152.4139],
#    [-33.3757, 151.9643],
#    [-33.3078, 151.5359],
#    [-33.7269, 151.3475]]},
#  'Marino dg-Miguel Domenech Martinez   MD': {'heading': 33,
#   'lat_dec': -32.0122,
#   'lon_dec': 153.9214,
#   'lastreport_heading': '33',
#   'lastreport_speed': '5.1',
#   'sail': '183268',
#   'status': None,
#   'wind': '83°, 9.2kn.',
#   'ubtname': 'Miguel Domenech Martinez   MD',
#   'usrname': 'Marino dg',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S32°0.73' E153°55.285', Hdg: 33°, Spd: 5.1kn., 3210.1nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 45190,
#   'rank': '26',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744385000.0,
#   'trackdistance': '253.339',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3210.07069727464',
#   'track': [[-32.0122, 153.9214],
#    [-32.3394, 153.8178],
#    [-32.6681, 153.8251],
#    [-32.9645, 153.8566],
#    [-33.3141, 153.8678],
#    [-33.7203, 153.8335],
#    [-33.7775, 152.9145],
#    [-33.6184, 152.4238],
#    [-33.6493, 152.1007],
#    [-34.065, 152.0379],
#    [-33.8603, 151.3517]]},
#  'Tellize-Celephais': {'heading': 350,
#   'lat_dec': -30.8268,
#   'lon_dec': 153.3161,
#   'lastreport_heading': '350',
#   'lastreport_speed': '5.3',
#   'sail': '191184',
#   'status': None,
#   'wind': '56°, 8.4kn.',
#   'ubtname': 'Celephais',
#   'usrname': 'Tellize',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°49.61' E153°18.967', Hdg: 350°, Spd: 5.3kn., 3135.7nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 46913,
#   'rank': '2',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744292000.0,
#   'trackdistance': '213.136',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3135.73505619968',
#   'track': [[-30.8268, 153.3161],
#    [-31.1029, 153.2162],
#    [-31.3406, 153.1489],
#    [-31.5337, 153.1128],
#    [-31.6912, 153.2039],
#    [-31.8402, 153.0113],
#    [-32.547, 152.572],
#    [-32.7458, 152.4016],
#    [-32.8919, 152.117],
#    [-33.027, 151.7967],
#    [-33.7534, 151.3853]]},
#  'lesud48-Black sheep': {'heading': 359,
#   'lat_dec': -32.1546,
#   'lon_dec': 153.6387,
#   'lastreport_heading': '359',
#   'lastreport_speed': '6.2',
#   'sail': '195197',
#   'status': None,
#   'wind': '73°, 10.9kn.',
#   'ubtname': 'Black sheep',
#   'usrname': 'lesud48',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S32°9.277' E153°38.324', Hdg: 359°, Spd: 6.2kn., 3207.3nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 45620,
#   'rank': '24',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744377000.0,
#   'trackdistance': '199.742',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3207.33711876214',
#   'track': [[-32.1546, 153.6387],
#    [-32.5313, 153.6874],
#    [-32.8655, 153.6981],
#    [-33.0211, 153.5847],
#    [-33.1019, 153.2338],
#    [-33.3591, 153.1686],
#    [-33.8975, 152.5119],
#    [-33.8304, 152.0216],
#    [-33.8395, 151.5634],
#    [-33.8554, 151.1996]]},
#  'isla hormiga c.palos-SS CARTAGENA\n': {'heading': 10,
#   'lat_dec': -30.9673,
#   'lon_dec': 153.6324,
#   'lastreport_heading': '10',
#   'lastreport_speed': '4.9',
#   'sail': '216715',
#   'status': None,
#   'wind': '68°, 7.9kn.',
#   'ubtname': 'SS CARTAGENA\n',
#   'usrname': 'isla hormiga c.palos',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°58.038' E153°37.944', Hdg: 10°, Spd: 4.9kn., 3152.7nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 33747,
#   'rank': '9',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744319000.0,
#   'trackdistance': '221.542',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3152.72022406311',
#   'track': [[-30.9673, 153.6324],
#    [-31.3273, 153.5882],
#    [-31.5948, 153.583],
#    [-31.719, 153.5317],
#    [-31.818, 153.2586],
#    [-31.915, 152.9401],
#    [-32.6859, 152.473],
#    [-33.0057, 152.3689],
#    [-33.3344, 152.2426],
#    [-33.4729, 151.9479],
#    [-33.7427, 151.349]]},
#  'stefan3-My boat': {'heading': 8,
#   'lat_dec': -31.1841,
#   'lon_dec': 153.7044,
#   'lastreport_heading': '8',
#   'lastreport_speed': '5.3',
#   'sail': '220937',
#   'status': None,
#   'wind': '71°, 8.5kn.',
#   'ubtname': 'My boat',
#   'usrname': 'stefan3',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°11.049' E153°42.261', Hdg: 8°, Spd: 5.3kn., 3165nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 13249,
#   'rank': '11',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744326000.0,
#   'trackdistance': '216.573',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3165.02138392219',
#   'track': [[-31.1841, 153.7044],
#    [-31.5463, 153.6501],
#    [-31.6125, 153.4326],
#    [-31.6349, 153.156],
#    [-31.8004, 152.9347],
#    [-31.8922, 152.6731],
#    [-32.6957, 152.4493],
#    [-33.0471, 152.3606],
#    [-33.158, 152.0771],
#    [-33.4011, 151.8473],
#    [-33.7719, 151.3378]]},
#  'bougnette-STELLA\t': {'heading': 17,
#   'lat_dec': -30.8569,
#   'lon_dec': 153.3918,
#   'lastreport_heading': '17',
#   'lastreport_speed': '4.7',
#   'sail': '223932',
#   'status': None,
#   'wind': '59°, 8.3kn.',
#   'ubtname': 'STELLA\t',
#   'usrname': 'bougnette',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°51.415' E153°23.506', Hdg: 17°, Spd: 4.7kn., 3139.6nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 47593,
#   'rank': '3',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744296000.0,
#   'trackdistance': '228.615',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3139.63606699269',
#   'track': [[-30.8569, 153.3918],
#    [-31.1452, 153.2609],
#    [-31.3985, 153.2209],
#    [-31.5877, 153.2157],
#    [-31.7488, 152.9817],
#    [-31.8807, 152.7191],
#    [-32.7383, 152.4683],
#    [-33.069, 152.3815],
#    [-33.4134, 152.2944],
#    [-33.7655, 152.1539],
#    [-33.8861, 151.4487]]},
#  'Buckaroo M-Yoyodyne': {'heading': 1,
#   'lat_dec': -31.3733,
#   'lon_dec': 153.9206,
#   'lastreport_heading': '1',
#   'lastreport_speed': '5.4',
#   'sail': '228494',
#   'status': None,
#   'wind': '82°, 8.1kn.',
#   'ubtname': 'Yoyodyne',
#   'usrname': 'Buckaroo M',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°22.398' E153°55.238', Hdg: 1°, Spd: 5.4kn., 3180.9nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 55403,
#   'rank': '16',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744345000.0,
#   'trackdistance': '267.602',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3180.86632600237',
#   'track': [[-31.3733, 153.9206],
#    [-31.7516, 153.9693],
#    [-32.046, 154.0046],
#    [-32.2721, 154.0316],
#    [-32.4008, 153.9158],
#    [-32.6672, 153.8169],
#    [-33.8049, 153.5416],
#    [-34.0465, 153.1604],
#    [-34.241, 152.8139],
#    [-34.1822, 152.332],
#    [-33.8869, 151.4246]]},
#  'O.S. Rich-T E Q U I L A  S U N R I S E': {'heading': 3,
#   'lat_dec': -32.1183,
#   'lon_dec': 153.5622,
#   'lastreport_heading': '3',
#   'lastreport_speed': '4.6',
#   'sail': '234119',
#   'status': None,
#   'wind': '71°, 11.3kn.',
#   'ubtname': 'T E Q U I L A  S U N R I S E',
#   'usrname': 'O.S. Rich',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S32°7.095' E153°33.731', Hdg: 3°, Spd: 4.6kn., 3203.2nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 46465,
#   'rank': '23',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744373000.0,
#   'trackdistance': '193.293',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3203.16483007399',
#   'track': [[-32.1183, 153.5622],
#    [-32.3603, 153.5955],
#    [-32.5932, 153.5921],
#    [-32.6003, 153.3851],
#    [-32.6344, 153.1867],
#    [-32.6915, 153.1651],
#    [-33.3753, 152.8716],
#    [-33.6152, 152.6963],
#    [-33.5075, 152.2611],
#    [-33.4293, 151.8494],
#    [-33.8218, 151.3032]]},
#  'Bluemoon TR-NBK': {'heading': 188,
#   'lat_dec': -38.2575,
#   'lon_dec': 149.2287,
#   'lastreport_heading': '188',
#   'lastreport_speed': '5.3',
#   'sail': '235249',
#   'status': None,
#   'wind': '233°, 15kn.',
#   'ubtname': 'NBK',
#   'usrname': 'Bluemoon TR',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S38°15.45' E149°13.725', Hdg: 188°, Spd: 5.3kn., 3374nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 43147,
#   'rank': '29',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744396000.0,
#   'trackdistance': '305.588',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3374.037105199',
#   'track': [[-38.2575, 149.2287],
#    [-38.111, 149.3746],
#    [-38.2302, 149.7441],
#    [-37.8702, 149.7248],
#    [-37.6834, 149.7568],
#    [-37.5948, 149.9214],
#    [-36.7768, 150.5042],
#    [-36.2386, 150.7969],
#    [-35.6591, 151.1117],
#    [-35.0367, 151.3631],
#    [-33.9654, 151.2819]]},
#  'chony-My boat': {'finishtime': '-',
#   'sail': '242668',
#   'status': 'Abandoned race',
#   'wind': None,
#   'ubtname': 'My boat',
#   'usrname': 'chony',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': '-',
#   'finished': 'true',
#   'teaname': None,
#   'usrnr': 54560,
#   'rank': 'DNF',
#   'btptype': "45' Ketch",
#   'racing': 0,
#   'timestamp': 1672629245000.0,
#   'trackdistance': '0.000',
#   'points': '0',
#   'nextmarknr': None,
#   'distancetonextmark': '3366.54780240777',
#   'track': []},
#  'anbushi-Ketchy Pride': {'heading': 12,
#   'lat_dec': -32.2681,
#   'lon_dec': 152.9306,
#   'lastreport_heading': '12',
#   'lastreport_speed': '4.6',
#   'sail': '249776',
#   'status': None,
#   'wind': '57°, 14.4kn.',
#   'ubtname': 'Ketchy Pride',
#   'usrname': 'anbushi',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S32°16.089' E152°55.837', Hdg: 12°, Spd: 4.6kn., 3189.7nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 60495,
#   'rank': '21',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744365000.0,
#   'trackdistance': '145.141',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3189.67062295145',
#   'track': [[-32.2681, 152.9306],
#    [-32.4097, 152.7879],
#    [-32.6507, 152.755],
#    [-32.6994, 152.4673],
#    [-32.7652, 152.1711],
#    [-33.2643, 152.0335],
#    [-33.4713, 151.9416],
#    [-33.6044, 151.7319],
#    [-33.6053, 151.3569],
#    [-33.8173, 151.2852]]},
#  'LightninCris-PssP2': {'heading': 5,
#   'lat_dec': -31.1219,
#   'lon_dec': 153.1783,
#   'lastreport_heading': '5',
#   'lastreport_speed': '4.4',
#   'sail': '251796',
#   'status': None,
#   'wind': '50°, 8.4kn.',
#   'ubtname': 'PssP2',
#   'usrname': 'LightninCris',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°7.317' E153°10.699', Hdg: 5°, Spd: 4.4kn., 3144.7nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 60837,
#   'rank': '7',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744311000.0,
#   'trackdistance': '228.584',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3144.70577623004',
#   'track': [[-31.1219, 153.1783],
#    [-31.3865, 153.4272],
#    [-31.5586, 153.6063],
#    [-31.6421, 153.5173],
#    [-31.7338, 153.2193],
#    [-31.8928, 152.9974],
#    [-32.648, 152.4981],
#    [-33.0155, 152.4363],
#    [-33.2061, 152.2162],
#    [-33.1484, 151.7883],
#    [-33.8145, 151.3825]]},
#  '*Seafarer*-HERA': {'heading': 25,
#   'lat_dec': -31.6867,
#   'lon_dec': 153.5825,
#   'lastreport_heading': '25',
#   'lastreport_speed': '5.2',
#   'sail': '252228',
#   'status': None,
#   'wind': '69°, 10.5kn.',
#   'ubtname': 'HERA',
#   'usrname': '*Seafarer*',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°41.202' E153°34.949', Hdg: 25°, Spd: 5.2kn., 3184nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 53353,
#   'rank': '17',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744349000.0,
#   'trackdistance': '224.456',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3183.98685682015',
#   'track': [[-31.6867, 153.5825],
#    [-32.0258, 153.5642],
#    [-32.34, 153.697],
#    [-32.6007, 153.7303],
#    [-32.6613, 153.4497],
#    [-32.611, 153.021],
#    [-33.3305, 152.71],
#    [-33.5691, 152.5955],
#    [-33.442, 152.1514],
#    [-33.6009, 151.8832],
#    [-33.8816, 151.3733]]},
#  'Shkiper-ANNA': {'heading': 66,
#   'lat_dec': -33.8595,
#   'lon_dec': 151.1986,
#   'lastreport_heading': '66',
#   'lastreport_speed': '0',
#   'sail': '252471',
#   'status': None,
#   'wind': '64°, 9.3kn.',
#   'ubtname': 'ANNA',
#   'usrname': 'Shkiper',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S33°51.57' E151°11.913', Hdg: 66°, Spd: 0kn., 0.1nm. to mark 1/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 61161,
#   'rank': '32',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672539195000.0,
#   'trackdistance': '0.000',
#   'points': '0',
#   'nextmarknr': '1',
#   'distancetonextmark': '0.119930050199058',
#   'track': [[-33.8595, 151.1986]]},
#  'brinn-SEMSTIX': {'heading': 27,
#   'lat_dec': -31.6151,
#   'lon_dec': 153.5032,
#   'lastreport_heading': '27',
#   'lastreport_speed': '4.1',
#   'sail': '252483',
#   'status': None,
#   'wind': '66°, 10.7kn.',
#   'ubtname': 'SEMSTIX',
#   'usrname': 'brinn',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°36.909' E153°30.192', Hdg: 27°, Spd: 4.1kn., 3178.1nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 61130,
#   'rank': '13',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744334000.0,
#   'trackdistance': '191.563',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3178.09124781264',
#   'track': [[-31.6151, 153.5032],
#    [-31.8958, 153.3456],
#    [-32.1599, 153.3435],
#    [-32.3959, 153.4357],
#    [-32.4524, 153.1804],
#    [-32.4629, 152.8853],
#    [-33.0035, 152.4424],
#    [-33.136, 152.2449],
#    [-33.3501, 152.0534],
#    [-33.339, 151.8568],
#    [-33.7426, 151.3309]]},
#  'Jarlei-My boat': {'heading': 69,
#   'lat_dec': -33.8595,
#   'lon_dec': 151.1988,
#   'lastreport_heading': '69',
#   'lastreport_speed': '0',
#   'sail': '253191',
#   'status': None,
#   'wind': '64°, 9.3kn.',
#   'ubtname': 'My boat',
#   'usrname': 'Jarlei',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S33°51.567' E151°11.929', Hdg: 69°, Spd: 0kn., 0.1nm. to mark 1/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 61415,
#   'rank': '31',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672593209000.0,
#   'trackdistance': '0.010',
#   'points': '0',
#   'nextmarknr': '1',
#   'distancetonextmark': '0.117826622837808',
#   'track': [[-33.8595, 151.1988], [-33.8595, 151.1986]]},
#  'FlyingFish-The Explorer': {'heading': 29,
#   'lat_dec': -32.3385,
#   'lon_dec': 153.856,
#   'lastreport_heading': '29',
#   'lastreport_speed': '5.5',
#   'sail': '253255',
#   'status': None,
#   'wind': '81°, 10.2kn.',
#   'ubtname': 'The Explorer',
#   'usrname': 'FlyingFish',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S32°20.312' E153°51.361', Hdg: 29°, Spd: 5.5kn., 3222.9nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 61384,
#   'rank': '27',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744388000.0,
#   'trackdistance': '166.779',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3222.88868981981',
#   'track': [[-32.3385, 153.856],
#    [-32.4215, 153.6122],
#    [-32.5539, 153.4393],
#    [-32.6764, 153.3014],
#    [-32.7168, 152.9495],
#    [-32.8373, 152.7332],
#    [-33.2559, 152.1727],
#    [-33.4246, 152.0068],
#    [-33.5148, 151.6983],
#    [-33.493, 151.4353],
#    [-33.807, 151.3087]]},
#  'Salty_Welshman-Belle of the Ballast': {'heading': 4,
#   'lat_dec': -30.9705,
#   'lon_dec': 153.3653,
#   'lastreport_heading': '4',
#   'lastreport_speed': '5.1',
#   'sail': '253327',
#   'status': None,
#   'wind': '56°, 8.8kn.',
#   'ubtname': 'Belle of the Ballast',
#   'usrname': 'Salty_Welshman',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°58.228' E153°21.918', Hdg: 4°, Spd: 5.1kn., 3144nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 43910,
#   'rank': '5',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744303000.0,
#   'trackdistance': '233.480',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3143.95230812832',
#   'track': [[-30.9705, 153.3653],
#    [-31.3084, 153.3433],
#    [-31.5757, 153.3582],
#    [-31.7901, 153.4512],
#    [-31.8849, 153.2871],
#    [-31.9323, 152.8983],
#    [-32.7514, 152.5337],
#    [-33.0714, 152.469],
#    [-33.1247, 152.1675],
#    [-33.0885, 151.7288],
#    [-33.7381, 151.3321]]},
#  'Gary B-KetchUp': {'heading': 10,
#   'lat_dec': -30.7277,
#   'lon_dec': 153.3151,
#   'lastreport_heading': '10',
#   'lastreport_speed': '4.9',
#   'sail': '253334',
#   'status': None,
#   'wind': '58°, 8.1kn.',
#   'ubtname': 'KetchUp',
#   'usrname': 'Gary B',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°43.661' E153°18.904', Hdg: 10°, Spd: 4.9kn., 3131.2nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 18533,
#   'rank': '1',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744289000.0,
#   'trackdistance': '217.699',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3131.16054148881',
#   'track': [[-30.7277, 153.3151],
#    [-31.0393, 153.2184],
#    [-31.3061, 153.1943],
#    [-31.4994, 153.1849],
#    [-31.6463, 152.9722],
#    [-31.7671, 152.887],
#    [-32.5831, 152.5269],
#    [-32.9426, 152.4295],
#    [-33.1754, 152.2151],
#    [-33.2361, 151.8842],
#    [-33.7292, 151.3654]]},
#  'Cap. Kiera-NUVOLA IV': {'finishtime': '-',
#   'sail': '253347',
#   'status': 'Abandoned race',
#   'wind': None,
#   'ubtname': 'NUVOLA IV',
#   'usrname': 'Cap. Kiera',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': '-',
#   'finished': 'true',
#   'teaname': None,
#   'usrnr': 61370,
#   'rank': 'DNF',
#   'btptype': "45' Ketch",
#   'racing': 0,
#   'timestamp': 1672611210000.0,
#   'trackdistance': '0.000',
#   'points': '0',
#   'nextmarknr': None,
#   'distancetonextmark': '3209.96601387568',
#   'track': []},
#  'Viper Vit-Petsamo': {'heading': 15,
#   'lat_dec': -31.2025,
#   'lon_dec': 153.6894,
#   'lastreport_heading': '15',
#   'lastreport_speed': '5.1',
#   'sail': '253392',
#   'status': None,
#   'wind': '70°, 8.6kn.',
#   'ubtname': 'Petsamo',
#   'usrname': 'Viper Vit',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°12.152' E153°41.364', Hdg: 15°, Spd: 5.1kn., 3165.4nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 59528,
#   'rank': '12',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744330000.0,
#   'trackdistance': '222.053',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3165.36254766841',
#   'track': [[-31.2025, 153.6894],
#    [-31.553, 153.6067],
#    [-31.8249, 153.5687],
#    [-31.9825, 153.5311],
#    [-32.0573, 153.2082],
#    [-32.1097, 152.8282],
#    [-32.8147, 152.4267],
#    [-32.9422, 152.2165],
#    [-33.2838, 152.1145],
#    [-33.6843, 152.0237],
#    [-33.8319, 151.3993]]},
#  'crit99-My boat': {'heading': 29,
#   'lat_dec': -31.49,
#   'lon_dec': 153.8784,
#   'lastreport_heading': '29',
#   'lastreport_speed': '5',
#   'sail': '253444',
#   'status': None,
#   'wind': '80°, 8.6kn.',
#   'ubtname': 'My boat',
#   'usrname': 'crit99',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S31°29.4' E153°52.702', Hdg: 29°, Spd: 5kn., 3184.8nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 45576,
#   'rank': '18',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744353000.0,
#   'trackdistance': '243.448',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3184.7789439558',
#   'track': [[-31.49, 153.8784],
#    [-31.7651, 153.691],
#    [-32.0241, 153.6216],
#    [-32.1369, 153.5108],
#    [-32.1824, 153.1429],
#    [-32.2136, 152.7264],
#    [-33.0818, 152.5501],
#    [-33.4255, 152.5604],
#    [-33.8188, 152.5347],
#    [-34.0563, 152.2745],
#    [-33.8906, 151.4307]]},
#  'Djon-NORD': {'heading': 22,
#   'lat_dec': -30.8817,
#   'lon_dec': 153.5716,
#   'lastreport_heading': '22',
#   'lastreport_speed': '4.4',
#   'sail': '253449',
#   'status': None,
#   'wind': '66°, 7.9kn.',
#   'ubtname': 'NORD',
#   'usrname': 'Djon',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S30°52.899' E153°34.298', Hdg: 22°, Spd: 4.4kn., 3146.8nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 54382,
#   'rank': '8',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744315000.0,
#   'trackdistance': '223.562',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3146.77738495857',
#   'track': [[-30.8817, 153.5716],
#    [-31.1619, 153.4114],
#    [-31.3964, 153.3793],
#    [-31.5744, 153.4297],
#    [-31.6951, 153.1462],
#    [-31.849, 153.0881],
#    [-32.5837, 152.5342],
#    [-32.9404, 152.4457],
#    [-32.9988, 152.1175],
#    [-33.1238, 151.7814],
#    [-33.7815, 151.3764]]},
#  'OldSillyRic-Esquechi Original': {'heading': 94,
#   'lat_dec': -34.803,
#   'lon_dec': 156.1542,
#   'lastreport_heading': '94',
#   'lastreport_speed': '5.3',
#   'sail': '253458',
#   'status': None,
#   'wind': '139°, 12.7kn.',
#   'ubtname': 'Esquechi Original',
#   'usrname': 'OldSillyRic',
#   'racetime': -1041372000,
#   'teamnr': 0,
#   'resultdescr': "S34°48.181' E156°9.253', Hdg: 94°, Spd: 5.3kn., 3410nm. to mark 2/13",
#   'finished': 'false',
#   'teaname': None,
#   'usrnr': 38909,
#   'rank': '30',
#   'btptype': "45' Ketch",
#   'racing': 1,
#   'timestamp': 1672744400000.0,
#   'trackdistance': '273.000',
#   'points': '0',
#   'nextmarknr': '2',
#   'distancetonextmark': '3410.03033504708',
#   'track': [[-34.803, 156.1542],
#    [-34.7709, 155.7035],
#    [-34.8028, 155.3501],
#    [-34.59, 155.0238],
#    [-34.4556, 154.5498],
#    [-34.2807, 154.0118],
#    [-33.7223, 152.5894],
#    [-33.5722, 152.1232],
#    [-33.6645, 151.8896],
#    [-33.5104, 151.5765],
#    [-33.833, 151.2804]]}}

# %%
ranks=[ (boats[boat]['usrname'].upper(),
         boats[boat]['rank'],
         boats[boat]['resultdescr'].split(',')[1].replace(' Hdg: ', ''),
         boats[boat]['resultdescr'].split(',')[2].replace(' Spd: ', '').replace('kn.', ''),
         boats[boat]['resultdescr'].split(',')[3].split('nm')[0].split('.')[0].strip(),
         boats[boat]['resultdescr'].split(',')[3].split('mark ')[1],
         boats[boat]['resultdescr'].split(',')[0],
         str(boats[boat]['lat_dec']) + " " + str(boats[boat]['lon_dec'])
        )
       for boat in boats if 'heading' in boats[boat]
      ]

# %%
df=pd.DataFrame(ranks)
df.columns=['User', 'Rank', 'HDG', 'SPD', 'DTW', 'WPT', 'POS1', 'POS2']
df['Rank']=df['Rank'].astype(int)
df=df.set_index('Rank')
df.sort_values('Rank', ascending=True, inplace=True)

df.at[df[df['User']==me].index[0], 'User']='<======= ' + me + ' =======>'

# %%
behind=float(df[df.index==1]['DTW'][1]) - float(df[df['User'].str.contains(me)]['DTW'].values[0])
print(df)
print('')
print('Behind leader by: {} nm'.format(round(behind),2))
# Out:
#                              User   HDG  SPD   DTW   WPT  \
# Rank
# 1                          GARY B   10°  4.9  3131  2/13
# 2                         TELLIZE  350°  5.3  3135  2/13
# 3                       BOUGNETTE   17°  4.7  3139  2/13
# 4                        ENCELADE    5°  4.9  3142  2/13
# 5                  SALTY_WELSHMAN    4°  5.1  3144  2/13
# 6                       STORMGIRL    9°  5.2  3144  2/13
# 7                    LIGHTNINCRIS    5°  4.4  3144  2/13
# 8                            DJON   22°  4.4  3146  2/13
# 9            ISLA HORMIGA C.PALOS   10°  4.9  3152  2/13
# 10                        PTITGUY    8°  5.2  3161  2/13
# 11                        STEFAN3    8°  5.3  3165  2/13
# 12    <======= VIPER VIT =======>   15°  5.1  3165  2/13
# 13                          BRINN   27°  4.1  3178  2/13
# 14                        CHRIS66   17°  5.4  3178  2/13
# 15                     DARK ONE77   31°  4.8  3178  2/13
# 16                     BUCKAROO M    1°  5.4  3180  2/13
# 17                     *SEAFARER*   25°  5.2  3184  2/13
# 18                         CRIT99   29°    5  3184  2/13
# 19                        DBIRD64  352°  5.5  3186  2/13
# 20                      FREEQUEST   29°  5.1  3187  2/13
# 21                        ANBUSHI   12°  4.6  3189  2/13
# 22                         JERRY2    6°  5.3  3195  2/13
# 23                      O.S. RICH    3°  4.6  3203  2/13
# 24                        LESUD48  359°  6.2  3207  2/13
# 25                          TONY2  123°  5.1  3207  2/13
# 26                      MARINO DG   33°  5.1  3210  2/13
# 27                     FLYINGFISH   29°  5.5  3222  2/13
# 28                        STEIGER  266°  5.8  3319  2/13
# 29                    BLUEMOON TR  188°  5.3  3374  2/13
# 30                    OLDSILLYRIC   94°  5.3  3410  2/13
# 31                         JARLEI   69°    0     0  1/13
# 32                        SHKIPER   66°    0     0  1/13
#
#                           POS1               POS2
# Rank
# 1     S30°43.661' E153°18.904'  -30.7277 153.3151
# 2      S30°49.61' E153°18.967'  -30.8268 153.3161
# 3     S30°51.415' E153°23.506'  -30.8569 153.3918
# 4     S30°47.295' E153°33.323'  -30.7883 153.5554
# 5     S30°58.228' E153°21.918'  -30.9705 153.3653
# 6       S31°1.57' E153°17.498'  -31.0262 153.2916
# 7      S31°7.317' E153°10.699'  -31.1219 153.1783
# 8     S30°52.899' E153°34.298'  -30.8817 153.5716
# 9     S30°58.038' E153°37.944'  -30.9673 153.6324
# 10     S31°25.35' E153°15.944'  -31.4225 153.2657
# 11    S31°11.049' E153°42.261'  -31.1841 153.7044
# 12    S31°12.152' E153°41.364'  -31.2025 153.6894
# 13    S31°36.909' E153°30.192'  -31.6151 153.5032
# 14     S31°27.52' E153°43.515'  -31.4587 153.7252
# 15     S31°25.245' E153°47.35'  -31.4208 153.7892
# 16    S31°22.398' E153°55.238'  -31.3733 153.9206
# 17    S31°41.202' E153°34.949'  -31.6867 153.5825
# 18      S31°29.4' E153°52.702'    -31.49 153.8784
# 19    S31°27.464' E153°58.952'  -31.4577 153.9825
# 20        S31°41' E153°42.325'  -31.6833 153.7054
# 21    S32°16.089' E152°55.837'  -32.2681 152.9306
# 22      S32°13.93' E153°9.924'  -32.2322 153.1654
# 23     S32°7.095' E153°33.731'  -32.1183 153.5622
# 24     S32°9.277' E153°38.324'  -32.1546 153.6387
# 25     S32°3.453' E153°47.551'  -32.0575 153.7925
# 26      S32°0.73' E153°55.285'  -32.0122 153.9214
# 27    S32°20.312' E153°51.361'   -32.3385 153.856
# 28    S35°27.935' E152°14.077'  -35.4656 152.2346
# 29     S38°15.45' E149°13.725'  -38.2575 149.2287
# 30     S34°48.181' E156°9.253'   -34.803 156.1542
# 31    S33°51.567' E151°11.929'  -33.8595 151.1988
# 32     S33°51.57' E151°11.913'  -33.8595 151.1986
#
# Behind leader by: -34 nm
